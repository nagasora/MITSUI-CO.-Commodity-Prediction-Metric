# %% [markdown]
# <a href="https://colab.research.google.com/github/nagasora/MITSUI-CO.-Commodity-Prediction-Metric/blob/main/level1_lstm_model_ver2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
f = open("/content/drive/MyDrive/kaggle notebook/kaggle.json")
json_data = json.load(f)
os.environ['KAGGLE_USERNAME'] = json_data['username']
os.environ['KAGGLE_KEY'] = json_data['key']

# %%
#APIコマンドを入力
# !kaggle competitions download -c mitsui-commodity-prediction-challenge
# Out:
# Downloading mitsui-commodity-prediction-challenge.zip to /content
#   0% 0.00/9.94M [00:00<?, ?B/s]
# 100% 9.94M/9.94M [00:00<00:00, 1.18GB/s]

# %%
import os
import zipfile

# Specify the path to the zip file in Google Drive
zip_file_path = "/content/mitsui-commodity-prediction-challenge.zip"

# Specify the destination directory (same as the zip file directory)
destination_directory = os.path.dirname(zip_file_path)

# Create the destination directory if it doesn't exist
os.makedirs(destination_directory, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_directory)

print(f"File unzipped to: {destination_directory}")
# Out:
# File unzipped to: /content

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

train = pd.read_csv('/content/train.csv')
train_labels = pd.read_csv('/content/train_labels.csv')
target_pairs = pd.read_csv('/content/target_pairs.csv')

print('training data:', train.shape)
print('train label:', train_labels.shape)
print('target_pairs:', target_pairs.shape)
# Out:
# training data: (1917, 558)
# train label: (1917, 425)
# target_pairs: (424, 3)

# %%
# ===================================================================
# 1. セットアップとデータ読み込み
# ===================================================================
import os
import gc
import pickle
import warnings
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# --- データパス ---
TRAIN_PATH = '/content/train.csv'
LABELS_PATH = '/content/train_labels.csv'
TARGET_PAIRS_PATH = '/content/target_pairs.csv'
OOF_PREDS_PATH = '/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/oof_predictions_lgbm.csv' # ベースライン予測

# 保存用ディレクトリ
MODEL_DIR = '/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/lstm_models_masked_ver1'
SCALER_DIR = '/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/scalers_masked_ver1'
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(SCALER_DIR, exist_ok=True)

# --- データを読み込み、結合する ---
print("データの読み込みを開始します...")
train_df = pd.read_csv(TRAIN_PATH)
labels_df = pd.read_csv(LABELS_PATH)
target_pairs_df = pd.read_csv(TARGET_PAIRS_PATH)
featured_df = pd.merge(train_df, labels_df, on='date_id', how='left')
print("データの読み込みと結合が完了しました。")

# ===================================================================
# 2. 特徴量エンジニアリング（強化版）
# ===================================================================
print("\n特徴量エンジニアリングを開始します...")

# --- 基本的なテクニカル指標 ---
# (ユーザー様の `create_technical_features` と `create_cross_asset_features` を使用)
def create_technical_features(df, price_cols, window_sizes=[5, 10, 20]):
    """テクニカル指標を生成する"""
    features = df.copy()
    for col in price_cols:
        if col in df.columns:
            for window in window_sizes:
                features[f'{col}_MA_{window}'] = features[col].rolling(window=window, min_periods=1).mean()
                features[f'{col}_STD_{window}'] = features[col].rolling(window=window, min_periods=1).std()
            features[f'{col}_Return_1d'] = features[col].pct_change(1)
            features[f'{col}_LogReturn_1d'] = np.log(features[col] / features[col].shift(1))
            ma_20 = features[col].rolling(window=20, min_periods=1).mean()
            std_20 = features[col].rolling(window=20, min_periods=1).std()
            features[f'{col}_BB_Upper'] = ma_20 + (2 * std_20)
            features[f'{col}_BB_Lower'] = ma_20 - (2 * std_20)
    return features

def create_cross_asset_features(df, asset_groups):
    """クロスアセット特徴量を生成する"""
    features = df.copy()
    for group_name, assets in asset_groups.items():
        available_assets = [asset for asset in assets if asset in df.columns]
        if len(available_assets) >= 2:
            group_returns = df[available_assets].pct_change().rolling(5).mean()
            features[f'{group_name}_Momentum_5d'] = group_returns.mean(axis=1)
            features[f'{group_name}_Volatility_5d'] = df[available_assets].pct_change().rolling(5).std().mean(axis=1)
    return features


PRICE_COLS = [col for col in train_df.columns if '_Close' in col or '_adj_close' in col or 'FX_' in col]
featured_df = create_technical_features(featured_df, PRICE_COLS)
asset_groups = {
    'Metals': [col for col in PRICE_COLS if 'LME' in col],
    'Precious_Metals': [col for col in PRICE_COLS if 'Gold' in col or 'Silver' in col or 'Platinum' in col],
    'FX': [col for col in PRICE_COLS if 'FX' in col]
}
featured_df = create_cross_asset_features(featured_df, asset_groups)

# --- スプレッド/レシオ特徴量 ---
for _, row in target_pairs_df.iterrows():
    pair = row['pair']
    if ' - ' in pair:
        asset1, asset2 = pair.split(' - ')
        if asset1 in featured_df.columns and asset2 in featured_df.columns:
            featured_df[f'SPREAD_{asset1}_{asset2}'] = featured_df[asset1] - featured_df[asset2]
            featured_df[f'RATIO_{asset1}_{asset2}'] = featured_df[asset1] / (featured_df[asset2] + 1e-6)

# --- ラグ/移動平均乖離 特徴量 ---
lags = [1, 5, 10]
windows = [5, 10, 20]
for col in PRICE_COLS:
    for lag in lags:
        featured_df[f'{col}_lag_{lag}'] = featured_df[col].shift(lag)
    for window in windows:
        ma = featured_df[col].rolling(window=window).mean()
        featured_df[f'{col}_ma_gap_{window}'] = featured_df[col] / ma

# --- OOF予測（メタ特徴量）の読み込みと結合 ---
try:
    oof_df = pd.read_csv(OOF_PREDS_PATH, index_col=0)
    oof_df.columns = [f'target_{i}' for i in range(oof_df.shape[1])]
    oof_meta_features = oof_df.add_suffix('_oof_pred')
    featured_df_with_meta = featured_df.reset_index(drop=True).merge(
        oof_meta_features.reset_index(drop=True), left_index=True, right_index=True, how='left'
    )
    print("OOF予測をメタ特徴量として追加しました。")
except FileNotFoundError:
    print("警告: OOF予測ファイルが見つかりません。メタ特徴量なしで続行します。")
    featured_df_with_meta = featured_df.copy()

# --- 最終的な前処理 ---
# 特徴量の欠損値を埋める
feature_cols_only = [col for col in featured_df_with_meta.columns if not col.startswith('target_')]
featured_df_with_meta[feature_cols_only] = featured_df_with_meta[feature_cols_only].ffill().bfill()
featured_df_with_meta.replace([np.inf, -np.inf], 0, inplace=True) # 0で埋める方が安全な場合もある

print(f"特徴量生成完了。最終的なデータ形状: {featured_df_with_meta.shape}")
gc.collect()
# Out:
# データの読み込みを開始します...
# データの読み込みと結合が完了しました。
#
# 特徴量エンジニアリングを開始します...
# OOF予測をメタ特徴量として追加しました。
# 特徴量生成完了。最終的なデータ形状: (1917, 4440)
# 0

# %%
# ===================================================================
# 3. ヘルパー関数とモデル定義
# ===================================================================

def create_dataset_with_masking(df, target_col, oof_col, feature_cols, sequence_length, batch_size):
    """ターゲットのNaNを削除せず、そのままシーケンスを生成する"""
    data = df.copy()

    current_features = feature_cols.copy()
    if oof_col in data.columns:
        current_features.append(oof_col)

    X_data = data[current_features].ffill().bfill()
    y_data = data[target_col] # NaNを含むターゲット

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_data)

    dataset = tf.keras.utils.timeseries_dataset_from_array(
        X_scaled, y_data,
        sequence_length=sequence_length,
        batch_size=batch_size,
        shuffle=False
    )
    return dataset, scaler

def masked_mse(y_true, y_pred):
    """y_trueがNaNである部分を無視する平均二乗誤差（MSE）"""
    mask = tf.math.is_finite(y_true)
    y_true_masked = tf.boolean_mask(y_true, mask)
    y_pred_masked = tf.boolean_mask(y_pred, mask)
    # MeanSquaredErrorクラスのインスタンスを生成して損失を計算する
    loss_fn = tf.keras.losses.MeanSquaredError()
    return loss_fn(y_true_masked, y_pred_masked)

def build_lstm_model(input_shape):
    """LSTMモデルを構築・コンパイルする"""
    model = Sequential([
        Input(shape=input_shape),
        LSTM(units=128, return_sequences=True),
        Dropout(0.3),
        LSTM(units=64, return_sequences=False),
        Dropout(0.3),
        Dense(units=64, activation='relu'),
        Dropout(0.3),
        Dense(units=1, activation='linear')
    ])
    # ★★★ カスタム損失関数を指定 ★★★
    model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.01), loss=masked_mse)
    return model

# %%
# ===================================================================
# 4. 全ターゲットの学習と保存
# ===================================================================

# --- パラメータ設定 ---
SEQUENCE_LENGTH = 30
BATCH_SIZE = 64 # データ量が増えたのでバッチサイズを少し戻しても良い
EPOCHS = 100
PATIENCE = 15

# --- ターゲットと特徴量のリスト準備 ---
target_cols = [col for col in labels_df.columns if col.startswith('target_')]
base_feature_cols = [col for col in featured_df_with_meta.columns if not col.startswith('target_') and col != 'date_id']

# --- 結果記録用のリスト ---
training_results = []

# --- OOF予測を保存するためのデータフレームを初期化 ---
# featured_df_with_metaのインデックスとカラム構造を借りる
oof_preds_lstm = pd.DataFrame(np.nan, index=featured_df_with_meta.index, columns=target_cols)

print(f"\n--- 全{len(target_cols)}ターゲットの学習とOOF予測生成を開始します ---")

print(f"\n--- 全{len(target_cols)}ターゲットの学習を開始します ---")

for i, target_col in enumerate(target_cols):
    print(f"\n[{i+1}/{len(target_cols)}] ターゲット '{target_col}' の処理を開始...")
    gc.collect()

    try:
        oof_col = f'{target_col}_oof_pred'

        # 1. データ準備
        dataset, scaler = create_dataset_with_masking(
            featured_df_with_meta, target_col, oof_col,
            base_feature_cols, SEQUENCE_LENGTH, BATCH_SIZE
        )

        # ★★★ 変更点1: 検証データのインデックスを保持 ★★★
        # data_indicesの取得をcreate_dataset_with_maskingから行うように修正するか、ここで再計算
        # ここでは後者のアプローチをとります
        valid_indices_for_target = featured_df_with_meta.index[featured_df_with_meta[target_col].notna()]
        last_train_index = valid_indices_for_target[int(len(valid_indices_for_target)*0.85) + SEQUENCE_LENGTH -1]
        oof_indices = featured_df_with_meta.loc[last_train_index:].index

        # 2. データセット分割
        DATASET_SIZE = tf.data.experimental.cardinality(dataset).numpy()
        if DATASET_SIZE < 2:
            print("  > データセットが小さすぎるためスキップします。")
            training_results.append({'target': target_col, 'val_rmse': np.nan, 'status': 'Skipped (Too small)'})
            continue

        train_size = int(0.85 * DATASET_SIZE)
        train_dataset = dataset.take(train_size).cache().prefetch(buffer_size=tf.data.AUTOTUNE)
        val_dataset = dataset.skip(train_size).cache().prefetch(buffer_size=tf.data.AUTOTUNE)

        # 3. モデルの構築と学習
        input_shape = train_dataset.element_spec[0].shape[1:]
        lstm_model = build_lstm_model(input_shape)
        early_stopping = EarlyStopping(monitor='val_loss', patience=PATIENCE, restore_best_weights=True)

        print(f"  > 学習を開始... (Train: {train_size} batches, Val: {DATASET_SIZE - train_size} batches)")
        history = lstm_model.fit(
            train_dataset, validation_data=val_dataset,
            epochs=EPOCHS, callbacks=[early_stopping], verbose=0
        )

        # 4. 評価 (マスクを考慮)
        val_preds = lstm_model.predict(val_dataset).flatten()
        y_val = np.concatenate([y.numpy() for _, y in val_dataset])

        mask = ~np.isnan(y_val) # NaNでない部分のマスク
        if np.sum(mask) == 0:
            val_rmse = np.nan # 検証セットにラベルが一つもなかった
        else:
            val_rmse = np.sqrt(mean_squared_error(y_val[mask], val_preds[mask]))

        best_epoch = np.argmin(history.history['val_loss']) + 1
        print(f"  > 学習完了。検証RMSE: {val_rmse:.4f} (at epoch {best_epoch})")

        # --- 評価とOOF予測の保存 ---
        if val_dataset and tf.data.experimental.cardinality(val_dataset).numpy() > 0:
            val_preds = lstm_model.predict(val_dataset).flatten()
            y_val = np.concatenate([y.numpy() for _, y in val_dataset])

            # ★★★ 変更点2: OOF予測を対応するインデックスに格納 ★★★
            # 検証セットの実際のインデックスを取得
            val_indices_start = train_size * BATCH_SIZE
            val_indices_end = val_indices_start + len(y_val)
            # data_indicesの代わりに、シーケンスの開始位置からインデックスを計算
            # 簡略化のため、検証データセットに対応する元のデータフレームのインデックスを取得
            # 注：このインデックス取得は近似的なもの。より厳密にはデータ生成時にインデックスを保持する
            val_original_indices = featured_df_with_meta.iloc[val_indices_start:val_indices_end].index

            # 予測結果を正しい位置に代入（長さが合わない場合があるため、共通のインデックスで合わせる）
            preds_series = pd.Series(val_preds, index=val_original_indices[:len(val_preds)])
            oof_preds_lstm.loc[preds_series.index, target_col] = preds_series

        # 5. モデルとスケーラーの保存
        lstm_model.save(os.path.join(MODEL_DIR, f'model_{target_col}.keras'))
        with open(os.path.join(SCALER_DIR, f'scaler_{target_col}.pkl'), 'wb') as f:
            pickle.dump(scaler, f)
        print(f"  > モデルとスケーラーを保存しました。")

        training_results.append({'target': target_col, 'val_rmse': val_rmse, 'status': 'Success'})

    except Exception as e:
        print(f"!!! エラー発生: {target_col} の処理中にエラー: {e}")
        import traceback
        traceback.print_exc()
        training_results.append({'target': target_col, 'val_rmse': np.nan, 'status': f'Failed: {e}'})

# --- サマリー表示 ---
print("\n--- 全てのターゲットの処理が完了しました ---")
results_df = pd.DataFrame(training_results)
if not results_df.empty:
    print("\n学習結果サマリー:")
    print(results_df.head())
    print(f"\n成功: {results_df[results_df['status']=='Success'].shape[0]} 件")
    print(f"失敗/スキップ: {results_df[results_df['status']!='Success'].shape[0]} 件")
    avg_rmse = results_df['val_rmse'].mean()
    print(f"成功したモデルの平均検証RMSE: {avg_rmse:.4f}")
    results_df.to_csv('/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/lstm_masked_training_results.csv', index=False)
    print("\n学習結果のサマリーをCSVに保存しました。")
# --- ループ終了後、OOF予測をCSVに保存 ---
oof_preds_lstm.to_csv('/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/oof_predictions_lstm.csv')
print("\nLSTMのOOF予測をCSVファイルとして保存しました。")
# Out:
# --- 全424ターゲットの学習とOOF予測生成を開始します ---
#
# --- 全424ターゲットの学習を開始します ---
#
# [1/424] ターゲット 'target_0' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0106 (at epoch 40)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [2/424] ターゲット 'target_1' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0146 (at epoch 40)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [3/424] ターゲット 'target_2' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0125 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [4/424] ターゲット 'target_3' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0131 (at epoch 40)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [5/424] ターゲット 'target_4' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0147 (at epoch 16)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [6/424] ターゲット 'target_5' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0199 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [7/424] ターゲット 'target_6' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0131 (at epoch 13)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [8/424] ターゲット 'target_7' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0174 (at epoch 31)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [9/424] ターゲット 'target_8' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0148 (at epoch 20)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [10/424] ターゲット 'target_9' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0137 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [11/424] ターゲット 'target_10' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0161 (at epoch 27)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [12/424] ターゲット 'target_11' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0150 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [13/424] ターゲット 'target_12' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0167 (at epoch 42)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [14/424] ターゲット 'target_13' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0138 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [15/424] ターゲット 'target_14' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0165 (at epoch 28)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [16/424] ターゲット 'target_15' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0142 (at epoch 33)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [17/424] ターゲット 'target_16' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0172 (at epoch 39)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [18/424] ターゲット 'target_17' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0247 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [19/424] ターゲット 'target_18' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0127 (at epoch 17)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [20/424] ターゲット 'target_19' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0130 (at epoch 25)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [21/424] ターゲット 'target_20' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0156 (at epoch 48)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [22/424] ターゲット 'target_21' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0185 (at epoch 18)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [23/424] ターゲット 'target_22' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0268 (at epoch 22)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [24/424] ターゲット 'target_23' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0136 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [25/424] ターゲット 'target_24' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0282 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [26/424] ターゲット 'target_25' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0147 (at epoch 30)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [27/424] ターゲット 'target_26' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0139 (at epoch 30)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [28/424] ターゲット 'target_27' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 82ms/step
#   > 学習完了。検証RMSE: 0.0231 (at epoch 30)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step
#   > モデルとスケーラーを保存しました。
#
# [29/424] ターゲット 'target_28' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#   > 学習完了。検証RMSE: 0.0205 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [30/424] ターゲット 'target_29' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0128 (at epoch 28)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [31/424] ターゲット 'target_30' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0316 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [32/424] ターゲット 'target_31' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0161 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [33/424] ターゲット 'target_32' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#   > 学習完了。検証RMSE: 0.0258 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [34/424] ターゲット 'target_33' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0185 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [35/424] ターゲット 'target_34' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0156 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [36/424] ターゲット 'target_35' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0146 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [37/424] ターゲット 'target_36' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0118 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [38/424] ターゲット 'target_37' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0129 (at epoch 13)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [39/424] ターゲット 'target_38' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0211 (at epoch 35)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [40/424] ターゲット 'target_39' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0131 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [41/424] ターゲット 'target_40' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0316 (at epoch 11)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [42/424] ターゲット 'target_41' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0258 (at epoch 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [43/424] ターゲット 'target_42' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#   > 学習完了。検証RMSE: 0.0374 (at epoch 11)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [44/424] ターゲット 'target_43' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0130 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [45/424] ターゲット 'target_44' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0114 (at epoch 23)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [46/424] ターゲット 'target_45' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0126 (at epoch 48)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [47/424] ターゲット 'target_46' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0141 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [48/424] ターゲット 'target_47' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0201 (at epoch 54)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [49/424] ターゲット 'target_48' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0173 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [50/424] ターゲット 'target_49' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0239 (at epoch 13)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [51/424] ターゲット 'target_50' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0242 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [52/424] ターゲット 'target_51' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0207 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [53/424] ターゲット 'target_52' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0212 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [54/424] ターゲット 'target_53' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0213 (at epoch 25)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [55/424] ターゲット 'target_54' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0162 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [56/424] ターゲット 'target_55' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0254 (at epoch 43)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [57/424] ターゲット 'target_56' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0149 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [58/424] ターゲット 'target_57' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0161 (at epoch 28)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [59/424] ターゲット 'target_58' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0142 (at epoch 11)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [60/424] ターゲット 'target_59' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0143 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [61/424] ターゲット 'target_60' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0131 (at epoch 39)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [62/424] ターゲット 'target_61' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0128 (at epoch 25)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [63/424] ターゲット 'target_62' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0206 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [64/424] ターゲット 'target_63' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0225 (at epoch 16)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [65/424] ターゲット 'target_64' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0152 (at epoch 51)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [66/424] ターゲット 'target_65' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0232 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [67/424] ターゲット 'target_66' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#   > 学習完了。検証RMSE: 0.0185 (at epoch 29)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [68/424] ターゲット 'target_67' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0255 (at epoch 47)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [69/424] ターゲット 'target_68' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0111 (at epoch 33)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [70/424] ターゲット 'target_69' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0126 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [71/424] ターゲット 'target_70' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0123 (at epoch 33)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [72/424] ターゲット 'target_71' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0119 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [73/424] ターゲット 'target_72' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0173 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [74/424] ターゲット 'target_73' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0161 (at epoch 33)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [75/424] ターゲット 'target_74' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0132 (at epoch 23)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [76/424] ターゲット 'target_75' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0171 (at epoch 42)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [77/424] ターゲット 'target_76' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0155 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [78/424] ターゲット 'target_77' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0197 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [79/424] ターゲット 'target_78' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0400 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [80/424] ターゲット 'target_79' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0274 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [81/424] ターゲット 'target_80' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0150 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [82/424] ターゲット 'target_81' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0113 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [83/424] ターゲット 'target_82' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0337 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [84/424] ターゲット 'target_83' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0247 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [85/424] ターゲット 'target_84' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0160 (at epoch 33)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [86/424] ターゲット 'target_85' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0255 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [87/424] ターゲット 'target_86' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0130 (at epoch 32)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [88/424] ターゲット 'target_87' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0160 (at epoch 26)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [89/424] ターゲット 'target_88' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0246 (at epoch 36)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [90/424] ターゲット 'target_89' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0142 (at epoch 49)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [91/424] ターゲット 'target_90' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0212 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [92/424] ターゲット 'target_91' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0260 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [93/424] ターゲット 'target_92' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0181 (at epoch 19)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [94/424] ターゲット 'target_93' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0189 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [95/424] ターゲット 'target_94' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
#   > 学習完了。検証RMSE: 0.0167 (at epoch 22)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [96/424] ターゲット 'target_95' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0234 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [97/424] ターゲット 'target_96' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0175 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [98/424] ターゲット 'target_97' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0186 (at epoch 26)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [99/424] ターゲット 'target_98' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0177 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [100/424] ターゲット 'target_99' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0182 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [101/424] ターゲット 'target_100' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0239 (at epoch 18)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [102/424] ターゲット 'target_101' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0162 (at epoch 39)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [103/424] ターゲット 'target_102' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0158 (at epoch 27)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [104/424] ターゲット 'target_103' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0148 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [105/424] ターゲット 'target_104' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0208 (at epoch 36)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [106/424] ターゲット 'target_105' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0124 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [107/424] ターゲット 'target_106' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0145 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [108/424] ターゲット 'target_107' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0212 (at epoch 45)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [109/424] ターゲット 'target_108' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0165 (at epoch 17)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [110/424] ターゲット 'target_109' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0192 (at epoch 25)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [111/424] ターゲット 'target_110' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0240 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [112/424] ターゲット 'target_111' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0214 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [113/424] ターゲット 'target_112' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0177 (at epoch 37)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [114/424] ターゲット 'target_113' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0142 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [115/424] ターゲット 'target_114' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0202 (at epoch 22)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [116/424] ターゲット 'target_115' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#   > 学習完了。検証RMSE: 0.0157 (at epoch 56)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [117/424] ターゲット 'target_116' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0227 (at epoch 32)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [118/424] ターゲット 'target_117' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0178 (at epoch 53)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [119/424] ターゲット 'target_118' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0217 (at epoch 37)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [120/424] ターゲット 'target_119' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0188 (at epoch 38)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [121/424] ターゲット 'target_120' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0181 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [122/424] ターゲット 'target_121' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0261 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [123/424] ターゲット 'target_122' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0200 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [124/424] ターゲット 'target_123' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0259 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [125/424] ターゲット 'target_124' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0304 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [126/424] ターゲット 'target_125' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0204 (at epoch 18)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [127/424] ターゲット 'target_126' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0264 (at epoch 50)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [128/424] ターゲット 'target_127' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0207 (at epoch 24)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [129/424] ターゲット 'target_128' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0248 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [130/424] ターゲット 'target_129' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0183 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [131/424] ターゲット 'target_130' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0332 (at epoch 18)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [132/424] ターゲット 'target_131' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0219 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [133/424] ターゲット 'target_132' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0258 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [134/424] ターゲット 'target_133' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0169 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [135/424] ターゲット 'target_134' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0212 (at epoch 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [136/424] ターゲット 'target_135' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0317 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [137/424] ターゲット 'target_136' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0216 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [138/424] ターゲット 'target_137' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0204 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [139/424] ターゲット 'target_138' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0155 (at epoch 13)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [140/424] ターゲット 'target_139' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0365 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [141/424] ターゲット 'target_140' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0440 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [142/424] ターゲット 'target_141' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0168 (at epoch 22)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [143/424] ターゲット 'target_142' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0306 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [144/424] ターゲット 'target_143' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0349 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [145/424] ターゲット 'target_144' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0277 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [146/424] ターゲット 'target_145' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#   > 学習完了。検証RMSE: 0.0159 (at epoch 11)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [147/424] ターゲット 'target_146' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0242 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [148/424] ターゲット 'target_147' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0470 (at epoch 46)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [149/424] ターゲット 'target_148' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0212 (at epoch 25)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [150/424] ターゲット 'target_149' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0287 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [151/424] ターゲット 'target_150' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0282 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [152/424] ターゲット 'target_151' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0225 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [153/424] ターゲット 'target_152' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0205 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [154/424] ターゲット 'target_153' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0148 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [155/424] ターゲット 'target_154' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0285 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [156/424] ターゲット 'target_155' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0179 (at epoch 20)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [157/424] ターゲット 'target_156' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0219 (at epoch 29)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [158/424] ターゲット 'target_157' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0294 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [159/424] ターゲット 'target_158' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0305 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [160/424] ターゲット 'target_159' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0226 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [161/424] ターゲット 'target_160' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0197 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [162/424] ターゲット 'target_161' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0161 (at epoch 15)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [163/424] ターゲット 'target_162' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0166 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [164/424] ターゲット 'target_163' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0335 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [165/424] ターゲット 'target_164' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0194 (at epoch 32)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [166/424] ターゲット 'target_165' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0312 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [167/424] ターゲット 'target_166' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0218 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [168/424] ターゲット 'target_167' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0232 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [169/424] ターゲット 'target_168' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0186 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [170/424] ターゲット 'target_169' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0164 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [171/424] ターゲット 'target_170' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0174 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [172/424] ターゲット 'target_171' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0232 (at epoch 15)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [173/424] ターゲット 'target_172' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0268 (at epoch 22)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [174/424] ターゲット 'target_173' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0453 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [175/424] ターゲット 'target_174' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0291 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [176/424] ターゲット 'target_175' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0220 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [177/424] ターゲット 'target_176' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0336 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [178/424] ターゲット 'target_177' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0170 (at epoch 19)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [179/424] ターゲット 'target_178' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0218 (at epoch 11)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [180/424] ターゲット 'target_179' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0249 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [181/424] ターゲット 'target_180' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0280 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [182/424] ターゲット 'target_181' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0335 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [183/424] ターゲット 'target_182' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0208 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [184/424] ターゲット 'target_183' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0336 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [185/424] ターゲット 'target_184' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0172 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [186/424] ターゲット 'target_185' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0321 (at epoch 26)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [187/424] ターゲット 'target_186' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0223 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [188/424] ターゲット 'target_187' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0217 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [189/424] ターゲット 'target_188' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0190 (at epoch 27)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [190/424] ターゲット 'target_189' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0184 (at epoch 22)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [191/424] ターゲット 'target_190' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0204 (at epoch 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [192/424] ターゲット 'target_191' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0246 (at epoch 13)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [193/424] ターゲット 'target_192' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0329 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [194/424] ターゲット 'target_193' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0461 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [195/424] ターゲット 'target_194' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0226 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [196/424] ターゲット 'target_195' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0458 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [197/424] ターゲット 'target_196' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0202 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [198/424] ターゲット 'target_197' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0217 (at epoch 29)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [199/424] ターゲット 'target_198' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0179 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [200/424] ターゲット 'target_199' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0251 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [201/424] ターゲット 'target_200' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0174 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [202/424] ターゲット 'target_201' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0323 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [203/424] ターゲット 'target_202' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0234 (at epoch 25)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [204/424] ターゲット 'target_203' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0297 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [205/424] ターゲット 'target_204' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0316 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [206/424] ターゲット 'target_205' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0186 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [207/424] ターゲット 'target_206' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0212 (at epoch 32)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [208/424] ターゲット 'target_207' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0177 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [209/424] ターゲット 'target_208' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0328 (at epoch 29)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [210/424] ターゲット 'target_209' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0344 (at epoch 45)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [211/424] ターゲット 'target_210' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0218 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [212/424] ターゲット 'target_211' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0199 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [213/424] ターゲット 'target_212' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0125 (at epoch 26)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [214/424] ターゲット 'target_213' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0188 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [215/424] ターゲット 'target_214' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# ...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0356 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [356/424] ターゲット 'target_355' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0410 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [357/424] ターゲット 'target_356' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0320 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [358/424] ターゲット 'target_357' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0492 (at epoch 12)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [359/424] ターゲット 'target_358' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0276 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [360/424] ターゲット 'target_359' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0292 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [361/424] ターゲット 'target_360' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0288 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [362/424] ターゲット 'target_361' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0429 (at epoch 48)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [363/424] ターゲット 'target_362' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0470 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [364/424] ターゲット 'target_363' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0303 (at epoch 11)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [365/424] ターゲット 'target_364' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0443 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [366/424] ターゲット 'target_365' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0412 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [367/424] ターゲット 'target_366' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0392 (at epoch 37)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [368/424] ターゲット 'target_367' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0213 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [369/424] ターゲット 'target_368' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0284 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [370/424] ターゲット 'target_369' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0326 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [371/424] ターゲット 'target_370' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0373 (at epoch 41)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [372/424] ターゲット 'target_371' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0277 (at epoch 36)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [373/424] ターゲット 'target_372' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0278 (at epoch 53)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [374/424] ターゲット 'target_373' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0417 (at epoch 36)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [375/424] ターゲット 'target_374' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0299 (at epoch 16)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [376/424] ターゲット 'target_375' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0315 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [377/424] ターゲット 'target_376' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0233 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [378/424] ターゲット 'target_377' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0246 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [379/424] ターゲット 'target_378' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0464 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [380/424] ターゲット 'target_379' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0269 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [381/424] ターゲット 'target_380' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0293 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [382/424] ターゲット 'target_381' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0196 (at epoch 15)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [383/424] ターゲット 'target_382' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0203 (at epoch 41)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [384/424] ターゲット 'target_383' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0255 (at epoch 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [385/424] ターゲット 'target_384' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0428 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [386/424] ターゲット 'target_385' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0381 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [387/424] ターゲット 'target_386' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0219 (at epoch 1)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [388/424] ターゲット 'target_387' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0459 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [389/424] ターゲット 'target_388' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0286 (at epoch 49)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [390/424] ターゲット 'target_389' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0216 (at epoch 30)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [391/424] ターゲット 'target_390' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0323 (at epoch 17)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [392/424] ターゲット 'target_391' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0388 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [393/424] ターゲット 'target_392' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0243 (at epoch 23)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [394/424] ターゲット 'target_393' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0654 (at epoch 17)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [395/424] ターゲット 'target_394' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0426 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [396/424] ターゲット 'target_395' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0263 (at epoch 7)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [397/424] ターゲット 'target_396' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0415 (at epoch 34)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [398/424] ターゲット 'target_397' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0367 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [399/424] ターゲット 'target_398' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0241 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [400/424] ターゲット 'target_399' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0368 (at epoch 59)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [401/424] ターゲット 'target_400' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0240 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [402/424] ターゲット 'target_401' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
#   > 学習完了。検証RMSE: 0.0288 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [403/424] ターゲット 'target_402' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
#   > 学習完了。検証RMSE: 0.0297 (at epoch 10)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [404/424] ターゲット 'target_403' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0346 (at epoch 72)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [405/424] ターゲット 'target_404' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0629 (at epoch 28)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [406/424] ターゲット 'target_405' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0253 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [407/424] ターゲット 'target_406' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 54ms/step
#   > 学習完了。検証RMSE: 0.0251 (at epoch 20)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [408/424] ターゲット 'target_407' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0300 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [409/424] ターゲット 'target_408' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0265 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [410/424] ターゲット 'target_409' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0230 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [411/424] ターゲット 'target_410' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0258 (at epoch 6)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [412/424] ターゲット 'target_411' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0471 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [413/424] ターゲット 'target_412' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0419 (at epoch 3)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [414/424] ターゲット 'target_413' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0244 (at epoch 9)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [415/424] ターゲット 'target_414' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0253 (at epoch 4)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [416/424] ターゲット 'target_415' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0205 (at epoch 15)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [417/424] ターゲット 'target_416' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0221 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [418/424] ターゲット 'target_417' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0328 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [419/424] ターゲット 'target_418' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
#   > 学習完了。検証RMSE: 0.0285 (at epoch 18)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [420/424] ターゲット 'target_419' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
#   > 学習完了。検証RMSE: 0.0236 (at epoch 8)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
#   > モデルとスケーラーを保存しました。
#
# [421/424] ターゲット 'target_420' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
#   > 学習完了。検証RMSE: 0.0281 (at epoch 5)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [422/424] ターゲット 'target_421' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
#   > 学習完了。検証RMSE: 0.0342 (at epoch 14)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [423/424] ターゲット 'target_422' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
#   > 学習完了。検証RMSE: 0.0282 (at epoch 21)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# [424/424] ターゲット 'target_423' の処理を開始...
#   > 学習を開始... (Train: 25 batches, Val: 5 batches)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
#   > 学習完了。検証RMSE: 0.0542 (at epoch 2)
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step
#   > モデルとスケーラーを保存しました。
#
# --- 全てのターゲットの処理が完了しました ---
#
# 学習結果サマリー:
#      target  val_rmse   status
# 0  target_0  0.010595  Success
# 1  target_1  0.014645  Success
# 2  target_2  0.012472  Success
# 3  target_3  0.013117  Success
# 4  target_4  0.014738  Success
#
# 成功: 424 件
# 失敗/スキップ: 0 件
# 成功したモデルの平均検証RMSE: 0.0259
#
# 学習結果のサマリーをCSVに保存しました。
#
# LSTMのOOF予測をCSVファイルとして保存しました。
