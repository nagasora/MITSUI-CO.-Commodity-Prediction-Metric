# %% [markdown]
# <a href="https://colab.research.google.com/github/nagasora/MITSUI-CO.-Commodity-Prediction-Metric/blob/main/basemodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install lightgbm

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import json
f = open("/content/drive/MyDrive/kaggle notebook/kaggle.json")
json_data = json.load(f)
os.environ['KAGGLE_USERNAME'] = json_data['username']
os.environ['KAGGLE_KEY'] = json_data['key']

# %%
#APIコマンドを入力
# !kaggle competitions download -c mitsui-commodity-prediction-challenge
# Out:
# mitsui-commodity-prediction-challenge.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
import os
import zipfile

# Specify the path to the zip file in Google Drive
zip_file_path = "/content/mitsui-commodity-prediction-challenge.zip"

# Specify the destination directory (same as the zip file directory)
destination_directory = os.path.dirname(zip_file_path)

# Create the destination directory if it doesn't exist
os.makedirs(destination_directory, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_directory)

print(f"File unzipped to: {destination_directory}")
# Out:
# File unzipped to: /content

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

train = pd.read_csv('/content/train.csv')
train_labels = pd.read_csv('/content/train_labels.csv')
target_pairs = pd.read_csv('/content/target_pairs.csv')

print('training data:', train.shape)
print('train label:', train_labels.shape)
print('target_pairs:', target_pairs.shape)
# Out:
# training data: (1917, 558)
# train label: (1917, 425)
# target_pairs: (424, 3)

# %%
"""
#データの結合
df_full = pd.merge(train, train_labels, on='date_id', how='left')

#欠損値の処理
feature_cols = [col for col in df_full.columns if col != 'date_id']
df_full[feature_cols] = df_full[feature_cols].fillna(method='ffill').fillna(method='bfill')

#特徴量エンジニアリング
def create_technical_features(df, price_cols, window_sizes=[5, 10, 20]):
    """"""Create technical indicators for price series""""""
    features = df.copy()

    for col in price_cols:
        if col in df.columns:
            # Moving averages
            for window in window_sizes:
                features[f'{col}_MA_{window}'] = df[col].rolling(window=window).mean()
                features[f'{col}_STD_{window}'] = df[col].rolling(window=window).std()

            # Price changes and returns
            features[f'{col}_Return_1d'] = df[col].pct_change(1)
            features[f'{col}_Return_5d'] = df[col].pct_change(5)
            features[f'{col}_LogReturn_1d'] = np.log(df[col] / df[col].shift(1))

            # Bollinger Bands
            ma_20 = df[col].rolling(window=20).mean()
            std_20 = df[col].rolling(window=20).std()
            features[f'{col}_BB_Upper'] = ma_20 + (2 * std_20)
            features[f'{col}_BB_Lower'] = ma_20 - (2 * std_20)
            features[f'{col}_BB_Position'] = (df[col] - features[f'{col}_BB_Lower']) / (features[f'{col}_BB_Upper'] - features[f'{col}_BB_Lower'])

            # RSI
            delta = df[col].diff()
            gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()
            loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()
            rs = gain / loss
            features[f'{col}_RSI'] = 100 - (100 / (1 + rs))

    return features

price_cols_for_feats = [col for col in df_full.columns if col != 'date_id']
df_featured = create_technical_features(df_full, price_cols_for_feats)
print("特徴量生成後のデータ形状:", df_featured.shape)

# 新しく作成されたカラムを確認
new_cols = [col for col in df_featured.columns if col not in df_full.columns]
print("生成された特徴量のサンプル:", new_cols[:5])

# 4. 無限大や追加のNaNを処理
df_featured.replace([np.inf, -np.inf], np.nan, inplace=True)
df_featured.fillna(method='ffill', inplace=True)
df_featured.fillna(method='bfill', inplace=True)
"""
# Out:
# '\n#データの結合\ndf_full = pd.merge(train, train_labels, on=\'date_id\', how=\'left\')\n\n#欠損値の処理\nfeature_cols = [col for col in df_full.columns if col != \'date_id\']\ndf_full[feature_cols] = df_full[feature_cols].fillna(method=\'ffill\').fillna(method=\'bfill\')\n\n#特徴量エンジニアリング\ndef create_technical_features(df, price_cols, window_sizes=[5, 10, 20]):\n    Create technical indicators for price series\n    features = df.copy()\n\n    for col in price_cols:\n        if col in df.columns:\n            # Moving averages\n            for window in window_sizes:\n                features[f\'{col}_MA_{window}\'] = df[col].rolling(window=window).mean()\n                features[f\'{col}_STD_{window}\'] = df[col].rolling(window=window).std()\n\n            # Price changes and returns\n            features[f\'{col}_Return_1d\'] = df[col].pct_change(1)\n            features[f\'{col}_Return_5d\'] = df[col].pct_change(5)\n            features[f\'{col}_LogReturn_1d\'] = np.log(df[col] / df[col].shift(1))\n\n            # Bollinger Bands\n            ma_20 = df[col].rolling(window=20).mean()\n            std_20 = df[col].rolling(window=20).std()\n            features[f\'{col}_BB_Upper\'] = ma_20 + (2 * std_20)\n            features[f\'{col}_BB_Lower\'] = ma_20 - (2 * std_20)\n            features[f\'{col}_BB_Position\'] = (df[col] - features[f\'{col}_BB_Lower\']) / (features[f\'{col}_BB_Upper\'] - features[f\'{col}_BB_Lower\'])\n\n            # RSI\n            delta = df[col].diff()\n            gain = (delta.where(delta > 0, 0)).rolling(window=14).mean()\n            loss = (-delta.where(delta < 0, 0)).rolling(window=14).mean()\n            rs = gain / loss\n            features[f\'{col}_RSI\'] = 100 - (100 / (1 + rs))\n\n    return features\n\nprice_cols_for_feats = [col for col in df_full.columns if col != \'date_id\']\ndf_featured = create_technical_features(df_full, price_cols_for_feats)\nprint("特徴量生成後のデータ形状:", df_featured.shape)\n\n# 新しく作成されたカラムを確認\nnew_cols = [col for col in df_featured.columns if col not in df_full.columns]\nprint("生成された特徴量のサンプル:", new_cols[:5])\n\n# 4. 無限大や追加のNaNを処理\ndf_featured.replace([np.inf, -np.inf], np.nan, inplace=True)\ndf_featured.fillna(method=\'ffill\', inplace=True)\ndf_featured.fillna(method=\'bfill\', inplace=True)\n'

# %%
"""
import lightgbm as lgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error

target_cols = [col for col in df_featured.columns if col.startswith('target_')]
featured_cols = [col for col in df_featured.columns if col not in target_cols and col != 'date_id']

target_to_train = 'target_0'

#学習データから、Nanを持つものを消去'
train_df = df_featured.dropna(subset=[target_to_train])
X = train_df[featured_cols]
y = train_df[target_to_train]

# --------------------------------------------------
# TimeSeriesSplit を使ったクロスバリデーション
# --------------------------------------------------
print(f"\n--- Training baseline model for {target_to_train} ---")

def cross_validation_strategy():
    cv_strategy = {
        'method': 'TimeSeriesSplit',
        'n_splits': 5,
        'gap': 5,  # Days between train and test
        'test_size': 90,  # Days in test set
        'expanding_window': True  # Use all previous data for training
    }
    return cv_strategy

cv_strategy = cross_validation_strategy()
tscv = TimeSeriesSplit(
    n_splits=cv_strategy['n_splits'],
    gap=cv_strategy['gap'],
    test_size=cv_strategy['test_size'],
)

oof_preds = np.zeros(len(X))
models = []
scores = []

for fold, (train_index, val_index) in enumerate(tscv.split(X)):
    print(f"--- Fold {fold+1} ---")
    X_train, X_val = X.iloc[train_index], X.iloc[val_index]
    y_train, y_val = y.iloc[train_index], y.iloc[val_index]

    # LightGBMモデルの定義
    lgb_params = {
        'objective': 'regression_l1', # MAE
        'metric': 'rmse', # RMSE
        'n_estimators': 1000,
        'learning_rate': 0.05,
        'feature_fraction': 0.8,
        'bagging_fraction': 0.8,
        'bagging_freq': 1,
        'lambda_l1': 0.1,
        'lambda_l2': 0.1,
        'num_leaves': 31,
        'verbose': -1,
        'n_jobs': -1,
        'seed': 42
    }

    model = lgb.LGBMRegressor(**lgb_params)

    # 学習
    model.fit(X_train, y_train,
              eval_set=[(X_val, y_val)],
              eval_metric='rmse',
              callbacks=[lgb.early_stopping(100, verbose=False)])

    # 評価
    val_preds = model.predict(X_val)
    oof_preds[val_index] = val_preds
    rmse = np.sqrt(mean_squared_error(y_val, val_preds))
    scores.append(rmse)
    print(f"Fold {fold+1} RMSE: {rmse:.4f}")
    models.append(model)

print(f"\nAverage CV RMSE: {np.mean(scores):.4f} (+/- {np.std(scores):.4f})")
"""
# Out:
# '\nimport lightgbm as lgb\nfrom sklearn.model_selection import TimeSeriesSplit\nfrom sklearn.metrics import mean_squared_error\n\ntarget_cols = [col for col in df_featured.columns if col.startswith(\'target_\')]\nfeatured_cols = [col for col in df_featured.columns if col not in target_cols and col != \'date_id\']\n\ntarget_to_train = \'target_0\'\n\n#学習データから、Nanを持つものを消去\'\ntrain_df = df_featured.dropna(subset=[target_to_train])\nX = train_df[featured_cols]\ny = train_df[target_to_train]\n\n# --------------------------------------------------\n# TimeSeriesSplit を使ったクロスバリデーション\n# --------------------------------------------------\nprint(f"\n--- Training baseline model for {target_to_train} ---")\n\ndef cross_validation_strategy():\n    cv_strategy = {\n        \'method\': \'TimeSeriesSplit\',\n        \'n_splits\': 5,\n        \'gap\': 5,  # Days between train and test\n        \'test_size\': 90,  # Days in test set\n        \'expanding_window\': True  # Use all previous data for training\n    }\n    return cv_strategy\n\ncv_strategy = cross_validation_strategy()\ntscv = TimeSeriesSplit(\n    n_splits=cv_strategy[\'n_splits\'],\n    gap=cv_strategy[\'gap\'],\n    test_size=cv_strategy[\'test_size\'],\n)\n\noof_preds = np.zeros(len(X))\nmodels = []\nscores = []\n\nfor fold, (train_index, val_index) in enumerate(tscv.split(X)):\n    print(f"--- Fold {fold+1} ---")\n    X_train, X_val = X.iloc[train_index], X.iloc[val_index]\n    y_train, y_val = y.iloc[train_index], y.iloc[val_index]\n\n    # LightGBMモデルの定義\n    lgb_params = {\n        \'objective\': \'regression_l1\', # MAE\n        \'metric\': \'rmse\', # RMSE\n        \'n_estimators\': 1000,\n        \'learning_rate\': 0.05,\n        \'feature_fraction\': 0.8,\n        \'bagging_fraction\': 0.8,\n        \'bagging_freq\': 1,\n        \'lambda_l1\': 0.1,\n        \'lambda_l2\': 0.1,\n        \'num_leaves\': 31,\n        \'verbose\': -1,\n        \'n_jobs\': -1,\n        \'seed\': 42\n    }\n\n    model = lgb.LGBMRegressor(**lgb_params)\n\n    # 学習\n    model.fit(X_train, y_train,\n              eval_set=[(X_val, y_val)],\n              eval_metric=\'rmse\',\n              callbacks=[lgb.early_stopping(100, verbose=False)])\n\n    # 評価\n    val_preds = model.predict(X_val)\n    oof_preds[val_index] = val_preds\n    rmse = np.sqrt(mean_squared_error(y_val, val_preds))\n    scores.append(rmse)\n    print(f"Fold {fold+1} RMSE: {rmse:.4f}")\n    models.append(model)\n\nprint(f"\nAverage CV RMSE: {np.mean(scores):.4f} (+/- {np.std(scores):.4f})")\n'

# %%
import numpy as np
import pandas as pd
import lightgbm as lgb
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import gc

TRAIN_PATH = '/content/train.csv'
LABELS_PATH = '/content/train_labels.csv'
TARGET_PAIRS_PATH = '/content/target_pairs.csv'

# 特徴量エンジニアリングで利用する価格カラム
# LME, JPX, US Stock, FX の主要なカラムをリストアップ
PRICE_COLS = [
    'LME_AH_Close', 'LME_CA_Close', 'LME_NI_Close', 'LME_PB_Close', 'LME_SN_Close', 'LME_ZS_Close',
    'JPX_Gold_Standard_Futures_Close', 'JPX_Silver_Standard_Futures_Close', 'JPX_Platinum_Standard_Futures_Close',
    'JPX_Palladium_Standard_Futures_Close', 'JPX_Nikkei_225_Futures_Close',
    'US_Stock_GLD_adj_close', 'US_Stock_SLV_adj_close', 'US_Stock_USO_adj_close', 'US_Stock_VT_adj_close',
    'FX_EURUSD', 'FX_USDJPY', 'FX_GBPUSD', 'FX_AUDUSD'
]

# モデルのパラメーター
LGB_params = {
    'objective': 'regression_l1',
    'metrics': 'rmse',
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'num_leaves': 31,
    'verbose': -1,
    'n_jobs': -1,
    'seed':42,
    'boosting_type': 'gbdt',
    'device': 'gpu'
    }

# クロスバリデーションの設定
N_SPLITS = 5
GAP = 5
TEST_SIZE = 90

print("設定が完了しました。")
# Out:
# 設定が完了しました。

# %%
# --- データ読み込みと前処理 ---

def load_data():
    """データを読み込み、結合する"""
    print("データの読み込みを開始します...")
    train_df = pd.read_csv(TRAIN_PATH)
    labels_df = pd.read_csv(LABELS_PATH)
    df = pd.merge(train_df, labels_df, on='date_id', how='left')
    print("データの読み込みと結合が完了しました。")
    return df

#特徴量エンジニアリング
def create_technical_features(df, price_cols, window_sizes=[5, 10, 20]):
    """テクニカル指標を生成する"""
    features = df.copy()
    for col in price_cols:
        if col in df.columns:
            for window in window_sizes:
                features[f'{col}_MA_{window}'] = features[col].rolling(window=window, min_periods=1).mean()
                features[f'{col}_STD_{window}'] = features[col].rolling(window=window, min_periods=1).std()
            features[f'{col}_Return_1d'] = features[col].pct_change(1)
            features[f'{col}_LogReturn_1d'] = np.log(features[col] / features[col].shift(1))
            ma_20 = features[col].rolling(window=20, min_periods=1).mean()
            std_20 = features[col].rolling(window=20, min_periods=1).std()
            features[f'{col}_BB_Upper'] = ma_20 + (2 * std_20)
            features[f'{col}_BB_Lower'] = ma_20 - (2 * std_20)
    return features

def create_cross_asset_features(df, asset_groups):
    """クロスアセット特徴量を生成する"""
    features = df.copy()
    for group_name, assets in asset_groups.items():
        available_assets = [asset for asset in assets if asset in df.columns]
        if len(available_assets) >= 2:
            group_returns = df[available_assets].pct_change().rolling(5).mean()
            features[f'{group_name}_Momentum_5d'] = group_returns.mean(axis=1)
            features[f'{group_name}_Volatility_5d'] = df[available_assets].pct_change().rolling(5).std().mean(axis=1)
    return features

def generate_features(df):
  print('特徴量生成を開始します。')

  df_features = df.ffill().bfill()
#テクニカル指標の作成
  df_features = create_technical_features(df_features, PRICE_COLS)
#クロスアセットの作成
  asset_groups = {
      'Metals': [col for col in PRICE_COLS if 'LME' in col],
      'Precious_Metals': [col for col in PRICE_COLS if 'Gold' in col or 'Silver' in col or 'Platinum' in col],
      'FX': [col for col in PRICE_COLS if 'FX' in col]
    }
  df_features = create_cross_asset_features(df_features, asset_groups)

  df_features.replace([np.inf, -np.inf], np.nan, inplace=True)
  df_features = df_features.ffill().bfill()

  print(f"特徴量作成完了. データ形状:{df_features.shape} ")
  return df_features

full_df = load_data()
featured_df = generate_features(full_df)

del full_df
gc.collect()
# Out:
# データの読み込みを開始します...
# データの読み込みと結合が完了しました。
# 特徴量生成を開始します。
# 特徴量作成完了. データ形状:(1917, 1118)
# 0

# %%
#モデル学習と評価
def train_and_evaluate(df):
  """全ターゲットに対してモデルを学習・評価し、結果を返す"""
  print("\nモデル学習と評価を開始します...")
  target_cols = [col for col in df.columns if col.startswith('target_')]
  featured_cols = [col for col in df.columns if col not in target_cols and col != 'date_id']

  oof_preds_df = pd.DataFrame(index=df.index)
  scores_list = []
  feature_importance_df = pd.DataFrame()

  # Define LGB_params inside the function to ensure correct parameters are used
  LGB_params = {
    'objective': 'regression_l1',
    'metrics': 'rmse',
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'feature_fraction': 0.8,
    'bagging_fraction': 0.8,
    'bagging_freq': 1,
    'lambda_l1': 0.1,
    'lambda_l2': 0.1,
    'num_leaves': 31,
    'verbose': -1,
    'n_jobs': -1,
    'seed':42,
    'boosting_type': 'gbdt',
    #'device': 'cuda'
  }


  # ↓↓↓ 全ターゲットで実行する場合はこの行をコメントアウト ↓↓↓
  # target_cols = target_cols[:5] # テスト用に最初の5つのターゲットに絞る
  # ↑↑↑ 全ターゲットで実行する場合はこの行をコメントアウト ↑↑↑

  for i, target in enumerate(target_cols):
    print(f"\n--- Processing Target {i+1}/{len(target_cols)}: {target} ---")

    #このターゲットのための学習データを準備
    temp_df = df.dropna(subset=[target])
    X = temp_df[featured_cols]
    y = temp_df[target]

    #クロスバリデーションの設定
    tscv = TimeSeriesSplit(n_splits=N_SPLITS, gap=GAP, test_size=TEST_SIZE)
    oof_preds = np.zeros(len(X))
    fold_models = []
    fold_scores = []
    fold_importances = pd.DataFrame(index=featured_cols)

    for fold, (train_index, val_index) in enumerate(tscv.split(X)):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model = lgb.LGBMRegressor(**LGB_params)
        model.fit(X_train, y_train,
                  eval_set=[(X_val, y_val)],
                  eval_metric='rmse',
                  callbacks=[lgb.early_stopping(100, verbose=False)])

    val_preds = model.predict(X_val)
    oof_preds[val_index] = val_preds
    rmse = np.sqrt(mean_squared_error(y_val, val_preds))
    fold_scores.append(rmse)

    fold_importances[f'fold_{fold+1}'] = model.feature_importances_
    fold_models.append(model)

    # 3. 結果の集計
    oof_preds_df[target] = pd.Series(oof_preds, index=X.index)
    avg_rmse = np.mean(fold_scores)
    std_rmse = np.std(fold_scores)
    scores_list.append({'target': target, 'avg_rmse': avg_rmse, 'std_rmse': std_rmse})
    print(f"Target {target} | Avg RMSE: {avg_rmse:.4f} (+/- {std_rmse:.4f})")

    # 特徴量重要度の集計
    feature_importance_df[target] = fold_importances.mean(axis=1)

  # 4. 最終結果をまとめる
  scores_df = pd.DataFrame(scores_list)
  return oof_preds_df, scores_df, feature_importance_df

# --- 実行 ---
oof_df, scores_df, importance_df = train_and_evaluate(featured_df)

print("\n--- 全ターゲットの学習が完了しました ---")
print("\n平均評価スコア:")
print(scores_df.head())
print(f"\n全ターゲットの平均RMSE: {scores_df['avg_rmse'].mean():.4f}")

print("\n特徴量重要度 (上位10件):")
# 全ターゲットでの重要度の平均を計算して表示
top_features = importance_df.mean(axis=1).sort_values(ascending=False).head(10)
print(top_features)


# --- 結果の保存 ---
# 必要に応じて、結果をファイルに保存します
oof_df.to_csv('/content/drive/MyDrive/oof_predictions_lgbm.csv')
scores_df.to_csv('/content/drive/MyDrive/scores_lgbm.csv', index=False)
importance_df.to_csv('/content/drive/MyDrive/feature_importance_lgbm.csv')
print("\n予測結果、スコア、特徴量重要度をCSVファイルとして保存しました。")
# Out:
# モデル学習と評価を開始します...
#
# --- Processing Target 1/424: target_0 ---
# Target target_0 | Avg RMSE: 0.0149 (+/- 0.0000)
#
# --- Processing Target 2/424: target_1 ---
# Target target_1 | Avg RMSE: 0.0175 (+/- 0.0000)
#
# --- Processing Target 3/424: target_2 ---
# Target target_2 | Avg RMSE: 0.0111 (+/- 0.0000)
#
# --- Processing Target 4/424: target_3 ---
# Target target_3 | Avg RMSE: 0.0096 (+/- 0.0000)
#
# --- Processing Target 5/424: target_4 ---
# Target target_4 | Avg RMSE: 0.0148 (+/- 0.0000)
#
# --- Processing Target 6/424: target_5 ---
# Target target_5 | Avg RMSE: 0.0146 (+/- 0.0000)
#
# --- Processing Target 7/424: target_6 ---
# Target target_6 | Avg RMSE: 0.0113 (+/- 0.0000)
#
# --- Processing Target 8/424: target_7 ---
# Target target_7 | Avg RMSE: 0.0172 (+/- 0.0000)
#
# --- Processing Target 9/424: target_8 ---
# Target target_8 | Avg RMSE: 0.0176 (+/- 0.0000)
#
# --- Processing Target 10/424: target_9 ---
# Target target_9 | Avg RMSE: 0.0138 (+/- 0.0000)
#
# --- Processing Target 11/424: target_10 ---
# Target target_10 | Avg RMSE: 0.0126 (+/- 0.0000)
#
# --- Processing Target 12/424: target_11 ---
# Target target_11 | Avg RMSE: 0.0165 (+/- 0.0000)
#
# --- Processing Target 13/424: target_12 ---
# Target target_12 | Avg RMSE: 0.0152 (+/- 0.0000)
#
# --- Processing Target 14/424: target_13 ---
# Target target_13 | Avg RMSE: 0.0145 (+/- 0.0000)
#
# --- Processing Target 15/424: target_14 ---
# Target target_14 | Avg RMSE: 0.0139 (+/- 0.0000)
#
# --- Processing Target 16/424: target_15 ---
# Target target_15 | Avg RMSE: 0.0123 (+/- 0.0000)
#
# --- Processing Target 17/424: target_16 ---
# Target target_16 | Avg RMSE: 0.0171 (+/- 0.0000)
#
# --- Processing Target 18/424: target_17 ---
# Target target_17 | Avg RMSE: 0.0319 (+/- 0.0000)
#
# --- Processing Target 19/424: target_18 ---
# Target target_18 | Avg RMSE: 0.0117 (+/- 0.0000)
#
# --- Processing Target 20/424: target_19 ---
# Target target_19 | Avg RMSE: 0.0149 (+/- 0.0000)
#
# --- Processing Target 21/424: target_20 ---
# Target target_20 | Avg RMSE: 0.0145 (+/- 0.0000)
#
# --- Processing Target 22/424: target_21 ---
# Target target_21 | Avg RMSE: 0.0165 (+/- 0.0000)
#
# --- Processing Target 23/424: target_22 ---
# Target target_22 | Avg RMSE: 0.0307 (+/- 0.0000)
#
# --- Processing Target 24/424: target_23 ---
# Target target_23 | Avg RMSE: 0.0138 (+/- 0.0000)
#
# --- Processing Target 25/424: target_24 ---
# Target target_24 | Avg RMSE: 0.0346 (+/- 0.0000)
#
# --- Processing Target 26/424: target_25 ---
# Target target_25 | Avg RMSE: 0.0164 (+/- 0.0000)
#
# --- Processing Target 27/424: target_26 ---
# Target target_26 | Avg RMSE: 0.0155 (+/- 0.0000)
#
# --- Processing Target 28/424: target_27 ---
# Target target_27 | Avg RMSE: 0.0261 (+/- 0.0000)
#
# --- Processing Target 29/424: target_28 ---
# Target target_28 | Avg RMSE: 0.0226 (+/- 0.0000)
#
# --- Processing Target 30/424: target_29 ---
# Target target_29 | Avg RMSE: 0.0119 (+/- 0.0000)
#
# --- Processing Target 31/424: target_30 ---
# Target target_30 | Avg RMSE: 0.0387 (+/- 0.0000)
#
# --- Processing Target 32/424: target_31 ---
# Target target_31 | Avg RMSE: 0.0176 (+/- 0.0000)
#
# --- Processing Target 33/424: target_32 ---
# Target target_32 | Avg RMSE: 0.0348 (+/- 0.0000)
#
# --- Processing Target 34/424: target_33 ---
# Target target_33 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 35/424: target_34 ---
# Target target_34 | Avg RMSE: 0.0123 (+/- 0.0000)
#
# --- Processing Target 36/424: target_35 ---
# Target target_35 | Avg RMSE: 0.0170 (+/- 0.0000)
#
# --- Processing Target 37/424: target_36 ---
# Target target_36 | Avg RMSE: 0.0109 (+/- 0.0000)
#
# --- Processing Target 38/424: target_37 ---
# Target target_37 | Avg RMSE: 0.0151 (+/- 0.0000)
#
# --- Processing Target 39/424: target_38 ---
# Target target_38 | Avg RMSE: 0.0197 (+/- 0.0000)
#
# --- Processing Target 40/424: target_39 ---
# Target target_39 | Avg RMSE: 0.0120 (+/- 0.0000)
#
# --- Processing Target 41/424: target_40 ---
# Target target_40 | Avg RMSE: 0.0439 (+/- 0.0000)
#
# --- Processing Target 42/424: target_41 ---
# Target target_41 | Avg RMSE: 0.0319 (+/- 0.0000)
#
# --- Processing Target 43/424: target_42 ---
# Target target_42 | Avg RMSE: 0.0384 (+/- 0.0000)
#
# --- Processing Target 44/424: target_43 ---
# Target target_43 | Avg RMSE: 0.0121 (+/- 0.0000)
#
# --- Processing Target 45/424: target_44 ---
# Target target_44 | Avg RMSE: 0.0115 (+/- 0.0000)
#
# --- Processing Target 46/424: target_45 ---
# Target target_45 | Avg RMSE: 0.0133 (+/- 0.0000)
#
# --- Processing Target 47/424: target_46 ---
# Target target_46 | Avg RMSE: 0.0161 (+/- 0.0000)
#
# --- Processing Target 48/424: target_47 ---
# Target target_47 | Avg RMSE: 0.0230 (+/- 0.0000)
#
# --- Processing Target 49/424: target_48 ---
# Target target_48 | Avg RMSE: 0.0190 (+/- 0.0000)
#
# --- Processing Target 50/424: target_49 ---
# Target target_49 | Avg RMSE: 0.0279 (+/- 0.0000)
#
# --- Processing Target 51/424: target_50 ---
# Target target_50 | Avg RMSE: 0.0302 (+/- 0.0000)
#
# --- Processing Target 52/424: target_51 ---
# Target target_51 | Avg RMSE: 0.0266 (+/- 0.0000)
#
# --- Processing Target 53/424: target_52 ---
# Target target_52 | Avg RMSE: 0.0254 (+/- 0.0000)
#
# --- Processing Target 54/424: target_53 ---
# Target target_53 | Avg RMSE: 0.0235 (+/- 0.0000)
#
# --- Processing Target 55/424: target_54 ---
# Target target_54 | Avg RMSE: 0.0130 (+/- 0.0000)
#
# --- Processing Target 56/424: target_55 ---
# Target target_55 | Avg RMSE: 0.0271 (+/- 0.0000)
#
# --- Processing Target 57/424: target_56 ---
# Target target_56 | Avg RMSE: 0.0135 (+/- 0.0000)
#
# --- Processing Target 58/424: target_57 ---
# Target target_57 | Avg RMSE: 0.0129 (+/- 0.0000)
#
# --- Processing Target 59/424: target_58 ---
# Target target_58 | Avg RMSE: 0.0171 (+/- 0.0000)
#
# --- Processing Target 60/424: target_59 ---
# Target target_59 | Avg RMSE: 0.0166 (+/- 0.0000)
#
# --- Processing Target 61/424: target_60 ---
# Target target_60 | Avg RMSE: 0.0135 (+/- 0.0000)
#
# --- Processing Target 62/424: target_61 ---
# Target target_61 | Avg RMSE: 0.0119 (+/- 0.0000)
#
# --- Processing Target 63/424: target_62 ---
# Target target_62 | Avg RMSE: 0.0254 (+/- 0.0000)
#
# --- Processing Target 64/424: target_63 ---
# Target target_63 | Avg RMSE: 0.0301 (+/- 0.0000)
#
# --- Processing Target 65/424: target_64 ---
# Target target_64 | Avg RMSE: 0.0134 (+/- 0.0000)
#
# --- Processing Target 66/424: target_65 ---
# Target target_65 | Avg RMSE: 0.0310 (+/- 0.0000)
#
# --- Processing Target 67/424: target_66 ---
# Target target_66 | Avg RMSE: 0.0197 (+/- 0.0000)
#
# --- Processing Target 68/424: target_67 ---
# Target target_67 | Avg RMSE: 0.0346 (+/- 0.0000)
#
# --- Processing Target 69/424: target_68 ---
# Target target_68 | Avg RMSE: 0.0116 (+/- 0.0000)
#
# --- Processing Target 70/424: target_69 ---
# Target target_69 | Avg RMSE: 0.0132 (+/- 0.0000)
#
# --- Processing Target 71/424: target_70 ---
# Target target_70 | Avg RMSE: 0.0151 (+/- 0.0000)
#
# --- Processing Target 72/424: target_71 ---
# Target target_71 | Avg RMSE: 0.0138 (+/- 0.0000)
#
# --- Processing Target 73/424: target_72 ---
# Target target_72 | Avg RMSE: 0.0145 (+/- 0.0000)
#
# --- Processing Target 74/424: target_73 ---
# Target target_73 | Avg RMSE: 0.0173 (+/- 0.0000)
#
# --- Processing Target 75/424: target_74 ---
# Target target_74 | Avg RMSE: 0.0147 (+/- 0.0000)
#
# --- Processing Target 76/424: target_75 ---
# Target target_75 | Avg RMSE: 0.0185 (+/- 0.0000)
#
# --- Processing Target 77/424: target_76 ---
# Target target_76 | Avg RMSE: 0.0131 (+/- 0.0000)
#
# --- Processing Target 78/424: target_77 ---
# Target target_77 | Avg RMSE: 0.0209 (+/- 0.0000)
#
# --- Processing Target 79/424: target_78 ---
# Target target_78 | Avg RMSE: 0.0616 (+/- 0.0000)
#
# --- Processing Target 80/424: target_79 ---
# Target target_79 | Avg RMSE: 0.0355 (+/- 0.0000)
#
# --- Processing Target 81/424: target_80 ---
# Target target_80 | Avg RMSE: 0.0192 (+/- 0.0000)
#
# --- Processing Target 82/424: target_81 ---
# Target target_81 | Avg RMSE: 0.0117 (+/- 0.0000)
#
# --- Processing Target 83/424: target_82 ---
# Target target_82 | Avg RMSE: 0.0486 (+/- 0.0000)
#
# --- Processing Target 84/424: target_83 ---
# Target target_83 | Avg RMSE: 0.0306 (+/- 0.0000)
#
# --- Processing Target 85/424: target_84 ---
# Target target_84 | Avg RMSE: 0.0150 (+/- 0.0000)
#
# --- Processing Target 86/424: target_85 ---
# Target target_85 | Avg RMSE: 0.0347 (+/- 0.0000)
#
# --- Processing Target 87/424: target_86 ---
# Target target_86 | Avg RMSE: 0.0109 (+/- 0.0000)
#
# --- Processing Target 88/424: target_87 ---
# Target target_87 | Avg RMSE: 0.0137 (+/- 0.0000)
#
# --- Processing Target 89/424: target_88 ---
# Target target_88 | Avg RMSE: 0.0276 (+/- 0.0000)
#
# --- Processing Target 90/424: target_89 ---
# Target target_89 | Avg RMSE: 0.0123 (+/- 0.0000)
#
# --- Processing Target 91/424: target_90 ---
# Target target_90 | Avg RMSE: 0.0285 (+/- 0.0000)
#
# --- Processing Target 92/424: target_91 ---
# Target target_91 | Avg RMSE: 0.0275 (+/- 0.0000)
#
# --- Processing Target 93/424: target_92 ---
# Target target_92 | Avg RMSE: 0.0172 (+/- 0.0000)
#
# --- Processing Target 94/424: target_93 ---
# Target target_93 | Avg RMSE: 0.0214 (+/- 0.0000)
#
# --- Processing Target 95/424: target_94 ---
# Target target_94 | Avg RMSE: 0.0171 (+/- 0.0000)
#
# --- Processing Target 96/424: target_95 ---
# Target target_95 | Avg RMSE: 0.0286 (+/- 0.0000)
#
# --- Processing Target 97/424: target_96 ---
# Target target_96 | Avg RMSE: 0.0222 (+/- 0.0000)
#
# --- Processing Target 98/424: target_97 ---
# Target target_97 | Avg RMSE: 0.0208 (+/- 0.0000)
#
# --- Processing Target 99/424: target_98 ---
# Target target_98 | Avg RMSE: 0.0198 (+/- 0.0000)
#
# --- Processing Target 100/424: target_99 ---
# Target target_99 | Avg RMSE: 0.0221 (+/- 0.0000)
#
# --- Processing Target 101/424: target_100 ---
# Target target_100 | Avg RMSE: 0.0258 (+/- 0.0000)
#
# --- Processing Target 102/424: target_101 ---
# Target target_101 | Avg RMSE: 0.0122 (+/- 0.0000)
#
# --- Processing Target 103/424: target_102 ---
# Target target_102 | Avg RMSE: 0.0140 (+/- 0.0000)
#
# --- Processing Target 104/424: target_103 ---
# Target target_103 | Avg RMSE: 0.0165 (+/- 0.0000)
#
# --- Processing Target 105/424: target_104 ---
# Target target_104 | Avg RMSE: 0.0242 (+/- 0.0000)
#
# --- Processing Target 106/424: target_105 ---
# Target target_105 | Avg RMSE: 0.0149 (+/- 0.0000)
#
# --- Processing Target 107/424: target_106 ---
# Target target_106 | Avg RMSE: 0.0192 (+/- 0.0000)
#
# --- Processing Target 108/424: target_107 ---
# Target target_107 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 109/424: target_108 ---
# Target target_108 | Avg RMSE: 0.0149 (+/- 0.0000)
#
# --- Processing Target 110/424: target_109 ---
# Target target_109 | Avg RMSE: 0.0216 (+/- 0.0000)
#
# --- Processing Target 111/424: target_110 ---
# Target target_110 | Avg RMSE: 0.0184 (+/- 0.0000)
#
# --- Processing Target 112/424: target_111 ---
# Target target_111 | Avg RMSE: 0.0238 (+/- 0.0000)
#
# --- Processing Target 113/424: target_112 ---
# Target target_112 | Avg RMSE: 0.0186 (+/- 0.0000)
#
# --- Processing Target 114/424: target_113 ---
# Target target_113 | Avg RMSE: 0.0144 (+/- 0.0000)
#
# --- Processing Target 115/424: target_114 ---
# Target target_114 | Avg RMSE: 0.0137 (+/- 0.0000)
#
# --- Processing Target 116/424: target_115 ---
# Target target_115 | Avg RMSE: 0.0180 (+/- 0.0000)
#
# --- Processing Target 117/424: target_116 ---
# Target target_116 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 118/424: target_117 ---
# Target target_117 | Avg RMSE: 0.0194 (+/- 0.0000)
#
# --- Processing Target 119/424: target_118 ---
# Target target_118 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 120/424: target_119 ---
# Target target_119 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 121/424: target_120 ---
# Target target_120 | Avg RMSE: 0.0147 (+/- 0.0000)
#
# --- Processing Target 122/424: target_121 ---
# Target target_121 | Avg RMSE: 0.0315 (+/- 0.0000)
#
# --- Processing Target 123/424: target_122 ---
# Target target_122 | Avg RMSE: 0.0219 (+/- 0.0000)
#
# --- Processing Target 124/424: target_123 ---
# Target target_123 | Avg RMSE: 0.0247 (+/- 0.0000)
#
# --- Processing Target 125/424: target_124 ---
# Target target_124 | Avg RMSE: 0.0323 (+/- 0.0000)
#
# --- Processing Target 126/424: target_125 ---
# Target target_125 | Avg RMSE: 0.0242 (+/- 0.0000)
#
# --- Processing Target 127/424: target_126 ---
# Target target_126 | Avg RMSE: 0.0269 (+/- 0.0000)
#
# --- Processing Target 128/424: target_127 ---
# Target target_127 | Avg RMSE: 0.0183 (+/- 0.0000)
#
# --- Processing Target 129/424: target_128 ---
# Target target_128 | Avg RMSE: 0.0227 (+/- 0.0000)
#
# --- Processing Target 130/424: target_129 ---
# Target target_129 | Avg RMSE: 0.0158 (+/- 0.0000)
#
# --- Processing Target 131/424: target_130 ---
# Target target_130 | Avg RMSE: 0.0354 (+/- 0.0000)
#
# --- Processing Target 132/424: target_131 ---
# Target target_131 | Avg RMSE: 0.0209 (+/- 0.0000)
#
# --- Processing Target 133/424: target_132 ---
# Target target_132 | Avg RMSE: 0.0261 (+/- 0.0000)
#
# --- Processing Target 134/424: target_133 ---
# Target target_133 | Avg RMSE: 0.0167 (+/- 0.0000)
#
# --- Processing Target 135/424: target_134 ---
# Target target_134 | Avg RMSE: 0.0187 (+/- 0.0000)
#
# --- Processing Target 136/424: target_135 ---
# Target target_135 | Avg RMSE: 0.0357 (+/- 0.0000)
#
# --- Processing Target 137/424: target_136 ---
# Target target_136 | Avg RMSE: 0.0207 (+/- 0.0000)
#
# --- Processing Target 138/424: target_137 ---
# Target target_137 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 139/424: target_138 ---
# Target target_138 | Avg RMSE: 0.0156 (+/- 0.0000)
#
# --- Processing Target 140/424: target_139 ---
# Target target_139 | Avg RMSE: 0.0461 (+/- 0.0000)
#
# --- Processing Target 141/424: target_140 ---
# Target target_140 | Avg RMSE: 0.0440 (+/- 0.0000)
#
# --- Processing Target 142/424: target_141 ---
# Target target_141 | Avg RMSE: 0.0148 (+/- 0.0000)
#
# --- Processing Target 143/424: target_142 ---
# Target target_142 | Avg RMSE: 0.0402 (+/- 0.0000)
#
# --- Processing Target 144/424: target_143 ---
# Target target_143 | Avg RMSE: 0.0358 (+/- 0.0000)
#
# --- Processing Target 145/424: target_144 ---
# Target target_144 | Avg RMSE: 0.0320 (+/- 0.0000)
#
# --- Processing Target 146/424: target_145 ---
# Target target_145 | Avg RMSE: 0.0194 (+/- 0.0000)
#
# --- Processing Target 147/424: target_146 ---
# Target target_146 | Avg RMSE: 0.0287 (+/- 0.0000)
#
# --- Processing Target 148/424: target_147 ---
# Target target_147 | Avg RMSE: 0.0461 (+/- 0.0000)
#
# --- Processing Target 149/424: target_148 ---
# Target target_148 | Avg RMSE: 0.0176 (+/- 0.0000)
#
# --- Processing Target 150/424: target_149 ---
# Target target_149 | Avg RMSE: 0.0288 (+/- 0.0000)
#
# --- Processing Target 151/424: target_150 ---
# Target target_150 | Avg RMSE: 0.0345 (+/- 0.0000)
#
# --- Processing Target 152/424: target_151 ---
# Target target_151 | Avg RMSE: 0.0210 (+/- 0.0000)
#
# --- Processing Target 153/424: target_152 ---
# Target target_152 | Avg RMSE: 0.0195 (+/- 0.0000)
#
# --- Processing Target 154/424: target_153 ---
# Target target_153 | Avg RMSE: 0.0158 (+/- 0.0000)
#
# --- Processing Target 155/424: target_154 ---
# Target target_154 | Avg RMSE: 0.0383 (+/- 0.0000)
#
# --- Processing Target 156/424: target_155 ---
# Target target_155 | Avg RMSE: 0.0167 (+/- 0.0000)
#
# --- Processing Target 157/424: target_156 ---
# Target target_156 | Avg RMSE: 0.0224 (+/- 0.0000)
#
# --- Processing Target 158/424: target_157 ---
# Target target_157 | Avg RMSE: 0.0344 (+/- 0.0000)
#
# --- Processing Target 159/424: target_158 ---
# Target target_158 | Avg RMSE: 0.0363 (+/- 0.0000)
#
# --- Processing Target 160/424: target_159 ---
# Target target_159 | Avg RMSE: 0.0203 (+/- 0.0000)
#
# --- Processing Target 161/424: target_160 ---
# Target target_160 | Avg RMSE: 0.0184 (+/- 0.0000)
#
# --- Processing Target 162/424: target_161 ---
# Target target_161 | Avg RMSE: 0.0137 (+/- 0.0000)
#
# --- Processing Target 163/424: target_162 ---
# Target target_162 | Avg RMSE: 0.0145 (+/- 0.0000)
#
# --- Processing Target 164/424: target_163 ---
# Target target_163 | Avg RMSE: 0.0384 (+/- 0.0000)
#
# --- Processing Target 165/424: target_164 ---
# Target target_164 | Avg RMSE: 0.0181 (+/- 0.0000)
#
# --- Processing Target 166/424: target_165 ---
# Target target_165 | Avg RMSE: 0.0367 (+/- 0.0000)
#
# --- Processing Target 167/424: target_166 ---
# Target target_166 | Avg RMSE: 0.0250 (+/- 0.0000)
#
# --- Processing Target 168/424: target_167 ---
# Target target_167 | Avg RMSE: 0.0221 (+/- 0.0000)
#
# --- Processing Target 169/424: target_168 ---
# Target target_168 | Avg RMSE: 0.0160 (+/- 0.0000)
#
# --- Processing Target 170/424: target_169 ---
# Target target_169 | Avg RMSE: 0.0160 (+/- 0.0000)
#
# --- Processing Target 171/424: target_170 ---
# Target target_170 | Avg RMSE: 0.0164 (+/- 0.0000)
#
# --- Processing Target 172/424: target_171 ---
# Target target_171 | Avg RMSE: 0.0184 (+/- 0.0000)
#
# --- Processing Target 173/424: target_172 ---
# Target target_172 | Avg RMSE: 0.0218 (+/- 0.0000)
#
# --- Processing Target 174/424: target_173 ---
# Target target_173 | Avg RMSE: 0.0534 (+/- 0.0000)
#
# --- Processing Target 175/424: target_174 ---
# Target target_174 | Avg RMSE: 0.0361 (+/- 0.0000)
#
# --- Processing Target 176/424: target_175 ---
# Target target_175 | Avg RMSE: 0.0205 (+/- 0.0000)
#
# --- Processing Target 177/424: target_176 ---
# Target target_176 | Avg RMSE: 0.0367 (+/- 0.0000)
#
# --- Processing Target 178/424: target_177 ---
# Target target_177 | Avg RMSE: 0.0165 (+/- 0.0000)
#
# --- Processing Target 179/424: target_178 ---
# Target target_178 | Avg RMSE: 0.0207 (+/- 0.0000)
#
# --- Processing Target 180/424: target_179 ---
# Target target_179 | Avg RMSE: 0.0202 (+/- 0.0000)
#
# --- Processing Target 181/424: target_180 ---
# Target target_180 | Avg RMSE: 0.0279 (+/- 0.0000)
#
# --- Processing Target 182/424: target_181 ---
# Target target_181 | Avg RMSE: 0.0432 (+/- 0.0000)
#
# --- Processing Target 183/424: target_182 ---
# Target target_182 | Avg RMSE: 0.0188 (+/- 0.0000)
#
# --- Processing Target 184/424: target_183 ---
# Target target_183 | Avg RMSE: 0.0389 (+/- 0.0000)
#
# --- Processing Target 185/424: target_184 ---
# Target target_184 | Avg RMSE: 0.0229 (+/- 0.0000)
#
# --- Processing Target 186/424: target_185 ---
# Target target_185 | Avg RMSE: 0.0294 (+/- 0.0000)
#
# --- Processing Target 187/424: target_186 ---
# Target target_186 | Avg RMSE: 0.0230 (+/- 0.0000)
#
# --- Processing Target 188/424: target_187 ---
# Target target_187 | Avg RMSE: 0.0170 (+/- 0.0000)
#
# --- Processing Target 189/424: target_188 ---
# Target target_188 | Avg RMSE: 0.0184 (+/- 0.0000)
#
# --- Processing Target 190/424: target_189 ---
# Target target_189 | Avg RMSE: 0.0200 (+/- 0.0000)
#
# --- Processing Target 191/424: target_190 ---
# Target target_190 | Avg RMSE: 0.0215 (+/- 0.0000)
#
# --- Processing Target 192/424: target_191 ---
# Target target_191 | Avg RMSE: 0.0251 (+/- 0.0000)
#
# --- Processing Target 193/424: target_192 ---
# Target target_192 | Avg RMSE: 0.0376 (+/- 0.0000)
#
# --- Processing Target 194/424: target_193 ---
# Target target_193 | Avg RMSE: 0.0656 (+/- 0.0000)
#
# --- Processing Target 195/424: target_194 ---
# Target target_194 | Avg RMSE: 0.0168 (+/- 0.0000)
#
# --- Processing Target 196/424: target_195 ---
# Target target_195 | Avg RMSE: 0.0536 (+/- 0.0000)
#
# --- Processing Target 197/424: target_196 ---
# Target target_196 | Avg RMSE: 0.0204 (+/- 0.0000)
#
# --- Processing Target 198/424: target_197 ---
# Target target_197 | Avg RMSE: 0.0161 (+/- 0.0000)
#
# --- Processing Target 199/424: target_198 ---
# Target target_198 | Avg RMSE: 0.0148 (+/- 0.0000)
#
# --- Processing Target 200/424: target_199 ---
# Target target_199 | Avg RMSE: 0.0340 (+/- 0.0000)
#
# --- Processing Target 201/424: target_200 ---
# Target target_200 | Avg RMSE: 0.0178 (+/- 0.0000)
#
# --- Processing Target 202/424: target_201 ---
# Target target_201 | Avg RMSE: 0.0324 (+/- 0.0000)
#
# --- Processing Target 203/424: target_202 ---
# Target target_202 | Avg RMSE: 0.0221 (+/- 0.0000)
#
# --- Processing Target 204/424: target_203 ---
# Target target_203 | Avg RMSE: 0.0311 (+/- 0.0000)
#
# --- Processing Target 205/424: target_204 ---
# Target target_204 | Avg RMSE: 0.0306 (+/- 0.0000)
#
# --- Processing Target 206/424: target_205 ---
# Target target_205 | Avg RMSE: 0.0217 (+/- 0.0000)
#
# --- Processing Target 207/424: target_206 ---
# Target target_206 | Avg RMSE: 0.0187 (+/- 0.0000)
#
# --- Processing Target 208/424: target_207 ---
# Target target_207 | Avg RMSE: 0.0236 (+/- 0.0000)
#
# --- Processing Target 209/424: target_208 ---
# Target target_208 | Avg RMSE: 0.0378 (+/- 0.0000)
#
# --- Processing Target 210/424: target_209 ---
# Target target_209 | Avg RMSE: 0.0456 (+/- 0.0000)
#
# --- Processing Target 211/424: target_210 ---
# Target target_210 | Avg RMSE: 0.0180 (+/- 0.0000)
#
# --- Processing Target 212/424: target_211 ---
# Target target_211 | Avg RMSE: 0.0193 (+/- 0.0000)
#
# --- Processing Target 213/424: target_212 ---
# Target target_212 | Avg RMSE: 0.0132 (+/- 0.0000)
#
# --- Processing Target 214/424: target_213 ---
# Target target_213 | Avg RMSE: 0.0141 (+/- 0.0000)
#
# --- Processing Target 215/424: target_214 ---
# Target target_214 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 216/424: target_215 ---
# Target target_215 | Avg RMSE: 0.0221 (+/- 0.0000)
#
# --- Processing Target 217/424: target_216 ---
# Target target_216 | Avg RMSE: 0.0230 (+/- 0.0000)
#
# --- Processing Target 218/424: target_217 ---
# Target target_217 | Avg RMSE: 0.0259 (+/- 0.0000)
#
# --- Processing Target 219/424: target_218 ---
# Target target_218 | Avg RMSE: 0.0169 (+/- 0.0000)
#
# --- Processing Target 220/424: target_219 ---
# Target target_219 | Avg RMSE: 0.0216 (+/- 0.0000)
#
# --- Processing Target 221/424: target_220 ---
# Target target_220 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 222/424: target_221 ---
# Target target_221 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 223/424: target_222 ---
# Target target_222 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 224/424: target_223 ---
# Target target_223 | Avg RMSE: 0.0197 (+/- 0.0000)
#
# --- Processing Target 225/424: target_224 ---
# Target target_224 | Avg RMSE: 0.0433 (+/- 0.0000)
#
# --- Processing Target 226/424: target_225 ---
# Target target_225 | Avg RMSE: 0.0322 (+/- 0.0000)
#
# --- Processing Target 227/424: target_226 ---
# Target target_226 | Avg RMSE: 0.0265 (+/- 0.0000)
#
# --- Processing Target 228/424: target_227 ---
# Target target_227 | Avg RMSE: 0.0257 (+/- 0.0000)
#
# --- Processing Target 229/424: target_228 ---
# Target target_228 | Avg RMSE: 0.0224 (+/- 0.0000)
#
# --- Processing Target 230/424: target_229 ---
# Target target_229 | Avg RMSE: 0.0230 (+/- 0.0000)
#
# --- Processing Target 231/424: target_230 ---
# Target target_230 | Avg RMSE: 0.0556 (+/- 0.0000)
#
# --- Processing Target 232/424: target_231 ---
# Target target_231 | Avg RMSE: 0.0207 (+/- 0.0000)
#
# --- Processing Target 233/424: target_232 ---
# Target target_232 | Avg RMSE: 0.0277 (+/- 0.0000)
#
# --- Processing Target 234/424: target_233 ---
# Target target_233 | Avg RMSE: 0.0258 (+/- 0.0000)
#
# --- Processing Target 235/424: target_234 ---
# Target target_234 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 236/424: target_235 ---
# Target target_235 | Avg RMSE: 0.0492 (+/- 0.0000)
#
# --- Processing Target 237/424: target_236 ---
# Target target_236 | Avg RMSE: 0.0199 (+/- 0.0000)
#
# --- Processing Target 238/424: target_237 ---
# Target target_237 | Avg RMSE: 0.0437 (+/- 0.0000)
#
# --- Processing Target 239/424: target_238 ---
# Target target_238 | Avg RMSE: 0.0238 (+/- 0.0000)
#
# --- Processing Target 240/424: target_239 ---
# Target target_239 | Avg RMSE: 0.0190 (+/- 0.0000)
#
# --- Processing Target 241/424: target_240 ---
# Target target_240 | Avg RMSE: 0.0183 (+/- 0.0000)
#
# --- Processing Target 242/424: target_241 ---
# Target target_241 | Avg RMSE: 0.0682 (+/- 0.0000)
#
# --- Processing Target 243/424: target_242 ---
# Target target_242 | Avg RMSE: 0.0287 (+/- 0.0000)
#
# --- Processing Target 244/424: target_243 ---
# Target target_243 | Avg RMSE: 0.0219 (+/- 0.0000)
#
# --- Processing Target 245/424: target_244 ---
# Target target_244 | Avg RMSE: 0.0534 (+/- 0.0000)
#
# --- Processing Target 246/424: target_245 ---
# Target target_245 | Avg RMSE: 0.0254 (+/- 0.0000)
#
# --- Processing Target 247/424: target_246 ---
# Target target_246 | Avg RMSE: 0.0400 (+/- 0.0000)
#
# --- Processing Target 248/424: target_247 ---
# Target target_247 | Avg RMSE: 0.0496 (+/- 0.0000)
#
# --- Processing Target 249/424: target_248 ---
# Target target_248 | Avg RMSE: 0.0491 (+/- 0.0000)
#
# --- Processing Target 250/424: target_249 ---
# Target target_249 | Avg RMSE: 0.0293 (+/- 0.0000)
#
# --- Processing Target 251/424: target_250 ---
# Target target_250 | Avg RMSE: 0.0149 (+/- 0.0000)
#
# --- Processing Target 252/424: target_251 ---
# Target target_251 | Avg RMSE: 0.0246 (+/- 0.0000)
#
# --- Processing Target 253/424: target_252 ---
# Target target_252 | Avg RMSE: 0.0472 (+/- 0.0000)
#
# --- Processing Target 254/424: target_253 ---
# Target target_253 | Avg RMSE: 0.0240 (+/- 0.0000)
#
# --- Processing Target 255/424: target_254 ---
# Target target_254 | Avg RMSE: 0.0216 (+/- 0.0000)
#
# --- Processing Target 256/424: target_255 ---
# Target target_255 | Avg RMSE: 0.0377 (+/- 0.0000)
#
# --- Processing Target 257/424: target_256 ---
# Target target_256 | Avg RMSE: 0.0260 (+/- 0.0000)
#
# --- Processing Target 258/424: target_257 ---
# Target target_257 | Avg RMSE: 0.0484 (+/- 0.0000)
#
# --- Processing Target 259/424: target_258 ---
# Target target_258 | Avg RMSE: 0.0211 (+/- 0.0000)
#
# --- Processing Target 260/424: target_259 ---
# Target target_259 | Avg RMSE: 0.0242 (+/- 0.0000)
#
# --- Processing Target 261/424: target_260 ---
# Target target_260 | Avg RMSE: 0.0180 (+/- 0.0000)
#
# --- Processing Target 262/424: target_261 ---
# Target target_261 | Avg RMSE: 0.0577 (+/- 0.0000)
#
# --- Processing Target 263/424: target_262 ---
# Target target_262 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 264/424: target_263 ---
# Target target_263 | Avg RMSE: 0.0390 (+/- 0.0000)
#
# --- Processing Target 265/424: target_264 ---
# Target target_264 | Avg RMSE: 0.0214 (+/- 0.0000)
#
# --- Processing Target 266/424: target_265 ---
# Target target_265 | Avg RMSE: 0.0240 (+/- 0.0000)
#
# --- Processing Target 267/424: target_266 ---
# Target target_266 | Avg RMSE: 0.0514 (+/- 0.0000)
#
# --- Processing Target 268/424: target_267 ---
# Target target_267 | Avg RMSE: 0.0714 (+/- 0.0000)
#
# --- Processing Target 269/424: target_268 ---
# Target target_268 | Avg RMSE: 0.0163 (+/- 0.0000)
#
# --- Processing Target 270/424: target_269 ---
# Target target_269 | Avg RMSE: 0.0374 (+/- 0.0000)
#
# --- Processing Target 271/424: target_270 ---
# Target target_270 | Avg RMSE: 0.0212 (+/- 0.0000)
#
# --- Processing Target 272/424: target_271 ---
# Target target_271 | Avg RMSE: 0.0259 (+/- 0.0000)
#
# --- Processing Target 273/424: target_272 ---
# Target target_272 | Avg RMSE: 0.0390 (+/- 0.0000)
#
# --- Processing Target 274/424: target_273 ---
# Target target_273 | Avg RMSE: 0.0297 (+/- 0.0000)
#
# --- Processing Target 275/424: target_274 ---
# Target target_274 | Avg RMSE: 0.0149 (+/- 0.0000)
#
# --- Processing Target 276/424: target_275 ---
# Target target_275 | Avg RMSE: 0.0228 (+/- 0.0000)
#
# --- Processing Target 277/424: target_276 ---
# Target target_276 | Avg RMSE: 0.0538 (+/- 0.0000)
#
# --- Processing Target 278/424: target_277 ---
# Target target_277 | Avg RMSE: 0.0182 (+/- 0.0000)
#
# --- Processing Target 279/424: target_278 ---
# Target target_278 | Avg RMSE: 0.0417 (+/- 0.0000)
#
# --- Processing Target 280/424: target_279 ---
# Target target_279 | Avg RMSE: 0.0214 (+/- 0.0000)
#
# --- Processing Target 281/424: target_280 ---
# Target target_280 | Avg RMSE: 0.0215 (+/- 0.0000)
#
# --- Processing Target 282/424: target_281 ---
# Target target_281 | Avg RMSE: 0.0203 (+/- 0.0000)
#
# --- Processing Target 283/424: target_282 ---
# Target target_282 | Avg RMSE: 0.0325 (+/- 0.0000)
#
# --- Processing Target 284/424: target_283 ---
# Target target_283 | Avg RMSE: 0.0207 (+/- 0.0000)
#
# --- Processing Target 285/424: target_284 ---
# Target target_284 | Avg RMSE: 0.0207 (+/- 0.0000)
#
# --- Processing Target 286/424: target_285 ---
# Target target_285 | Avg RMSE: 0.0230 (+/- 0.0000)
#
# --- Processing Target 287/424: target_286 ---
# Target target_286 | Avg RMSE: 0.0365 (+/- 0.0000)
#
# --- Processing Target 288/424: target_287 ---
# Target target_287 | Avg RMSE: 0.0417 (+/- 0.0000)
#
# --- Processing Target 289/424: target_288 ---
# Target target_288 | Avg RMSE: 0.0460 (+/- 0.0000)
#
# --- Processing Target 290/424: target_289 ---
# Target target_289 | Avg RMSE: 0.0294 (+/- 0.0000)
#
# --- Processing Target 291/424: target_290 ---
# Target target_290 | Avg RMSE: 0.0408 (+/- 0.0000)
#
# --- Processing Target 292/424: target_291 ---
# Target target_291 | Avg RMSE: 0.0240 (+/- 0.0000)
#
# --- Processing Target 293/424: target_292 ---
# Target target_292 | Avg RMSE: 0.0206 (+/- 0.0000)
#
# --- Processing Target 294/424: target_293 ---
# Target target_293 | Avg RMSE: 0.0325 (+/- 0.0000)
#
# --- Processing Target 295/424: target_294 ---
# Target target_294 | Avg RMSE: 0.0183 (+/- 0.0000)
#
# --- Processing Target 296/424: target_295 ---
# Target target_295 | Avg RMSE: 0.0177 (+/- 0.0000)
#
# --- Processing Target 297/424: target_296 ---
# Target target_296 | Avg RMSE: 0.0314 (+/- 0.0000)
#
# --- Processing Target 298/424: target_297 ---
# Target target_297 | Avg RMSE: 0.0365 (+/- 0.0000)
#
# --- Processing Target 299/424: target_298 ---
# Target target_298 | Avg RMSE: 0.0267 (+/- 0.0000)
#
# --- Processing Target 300/424: target_299 ---
# Target target_299 | Avg RMSE: 0.0200 (+/- 0.0000)
#
# --- Processing Target 301/424: target_300 ---
# Target target_300 | Avg RMSE: 0.0483 (+/- 0.0000)
#
# --- Processing Target 302/424: target_301 ---
# Target target_301 | Avg RMSE: 0.0196 (+/- 0.0000)
#
# --- Processing Target 303/424: target_302 ---
# Target target_302 | Avg RMSE: 0.0452 (+/- 0.0000)
#
# --- Processing Target 304/424: target_303 ---
# Target target_303 | Avg RMSE: 0.0276 (+/- 0.0000)
#
# --- Processing Target 305/424: target_304 ---
# Target target_304 | Avg RMSE: 0.0249 (+/- 0.0000)
#
# --- Processing Target 306/424: target_305 ---
# Target target_305 | Avg RMSE: 0.0315 (+/- 0.0000)
#
# --- Processing Target 307/424: target_306 ---
# Target target_306 | Avg RMSE: 0.0171 (+/- 0.0000)
#
# --- Processing Target 308/424: target_307 ---
# Target target_307 | Avg RMSE: 0.0376 (+/- 0.0000)
#
# --- Processing Target 309/424: target_308 ---
# Target target_308 | Avg RMSE: 0.0251 (+/- 0.0000)
#
# --- Processing Target 310/424: target_309 ---
# Target target_309 | Avg RMSE: 0.0186 (+/- 0.0000)
#
# --- Processing Target 311/424: target_310 ---
# Target target_310 | Avg RMSE: 0.0187 (+/- 0.0000)
#
# --- Processing Target 312/424: target_311 ---
# Target target_311 | Avg RMSE: 0.0244 (+/- 0.0000)
#
# --- Processing Target 313/424: target_312 ---
# Target target_312 | Avg RMSE: 0.0254 (+/- 0.0000)
#
# --- Processing Target 314/424: target_313 ---
# Target target_313 | Avg RMSE: 0.0427 (+/- 0.0000)
#
# --- Processing Target 315/424: target_314 ---
# Target target_314 | Avg RMSE: 0.0255 (+/- 0.0000)
#
# --- Processing Target 316/424: target_315 ---
# Target target_315 | Avg RMSE: 0.0447 (+/- 0.0000)
#
# --- Processing Target 317/424: target_316 ---
# Target target_316 | Avg RMSE: 0.0238 (+/- 0.0000)
#
# --- Processing Target 318/424: target_317 ---
# Target target_317 | Avg RMSE: 0.0346 (+/- 0.0000)
#
# --- Processing Target 319/424: target_318 ---
# Target target_318 | Avg RMSE: 0.0129 (+/- 0.0000)
#
# --- Processing Target 320/424: target_319 ---
# Target target_319 | Avg RMSE: 0.0209 (+/- 0.0000)
#
# --- Processing Target 321/424: target_320 ---
# Target target_320 | Avg RMSE: 0.0318 (+/- 0.0000)
#
# --- Processing Target 322/424: target_321 ---
# Target target_321 | Avg RMSE: 0.0147 (+/- 0.0000)
#
# --- Processing Target 323/424: target_322 ---
# Target target_322 | Avg RMSE: 0.0155 (+/- 0.0000)
#
# --- Processing Target 324/424: target_323 ---
# Target target_323 | Avg RMSE: 0.0186 (+/- 0.0000)
#
# --- Processing Target 325/424: target_324 ---
# Target target_324 | Avg RMSE: 0.0265 (+/- 0.0000)
#
# --- Processing Target 326/424: target_325 ---
# Target target_325 | Avg RMSE: 0.0666 (+/- 0.0000)
#
# --- Processing Target 327/424: target_326 ---
# Target target_326 | Avg RMSE: 0.0272 (+/- 0.0000)
#
# --- Processing Target 328/424: target_327 ---
# Target target_327 | Avg RMSE: 0.0331 (+/- 0.0000)
#
# --- Processing Target 329/424: target_328 ---
# Target target_328 | Avg RMSE: 0.0330 (+/- 0.0000)
#
# --- Processing Target 330/424: target_329 ---
# Target target_329 | Avg RMSE: 0.0871 (+/- 0.0000)
#
# --- Processing Target 331/424: target_330 ---
# Target target_330 | Avg RMSE: 0.0226 (+/- 0.0000)
#
# --- Processing Target 332/424: target_331 ---
# Target target_331 | Avg RMSE: 0.0495 (+/- 0.0000)
#
# --- Processing Target 333/424: target_332 ---
# Target target_332 | Avg RMSE: 0.0253 (+/- 0.0000)
#
# --- Processing Target 334/424: target_333 ---
# Target target_333 | Avg RMSE: 0.0442 (+/- 0.0000)
#
# --- Processing Target 335/424: target_334 ---
# Target target_334 | Avg RMSE: 0.0528 (+/- 0.0000)
#
# --- Processing Target 336/424: target_335 ---
# Target target_335 | Avg RMSE: 0.0512 (+/- 0.0000)
#
# --- Processing Target 337/424: target_336 ---
# Target target_336 | Avg RMSE: 0.0298 (+/- 0.0000)
#
# --- Processing Target 338/424: target_337 ---
# Target target_337 | Avg RMSE: 0.0286 (+/- 0.0000)
#
# --- Processing Target 339/424: target_338 ---
# Target target_338 | Avg RMSE: 0.0517 (+/- 0.0000)
#
# --- Processing Target 340/424: target_339 ---
# Target target_339 | Avg RMSE: 0.0251 (+/- 0.0000)
#
# --- Processing Target 341/424: target_340 ---
# Target target_340 | Avg RMSE: 0.0272 (+/- 0.0000)
#
# --- Processing Target 342/424: target_341 ---
# Target target_341 | Avg RMSE: 0.0238 (+/- 0.0000)
#
# --- Processing Target 343/424: target_342 ---
# Target target_342 | Avg RMSE: 0.0443 (+/- 0.0000)
#
# --- Processing Target 344/424: target_343 ---
# Target target_343 | Avg RMSE: 0.0571 (+/- 0.0000)
#
# --- Processing Target 345/424: target_344 ---
# Target target_344 | Avg RMSE: 0.0363 (+/- 0.0000)
#
# --- Processing Target 346/424: target_345 ---
# Target target_345 | Avg RMSE: 0.0214 (+/- 0.0000)
#
# --- Processing Target 347/424: target_346 ---
# Target target_346 | Avg RMSE: 0.0309 (+/- 0.0000)
#
# --- Processing Target 348/424: target_347 ---
# Target target_347 | Avg RMSE: 0.0293 (+/- 0.0000)
#
# --- Processing Target 349/424: target_348 ---
# Target target_348 | Avg RMSE: 0.0257 (+/- 0.0000)
#
# --- Processing Target 350/424: target_349 ---
# Target target_349 | Avg RMSE: 0.0214 (+/- 0.0000)
#
# --- Processing Target 351/424: target_350 ---
# Target target_350 | Avg RMSE: 0.0231 (+/- 0.0000)
#
# --- Processing Target 352/424: target_351 ---
# Target target_351 | Avg RMSE: 0.0261 (+/- 0.0000)
#
# --- Processing Target 353/424: target_352 ---
# Target target_352 | Avg RMSE: 0.0504 (+/- 0.0000)
#
# --- Processing Target 354/424: target_353 ---
# Target target_353 | Avg RMSE: 0.0248 (+/- 0.0000)
#
# --- Processing Target 355/424: target_354 ---
# Target target_354 | Avg RMSE: 0.0349 (+/- 0.0000)
#
# --- Processing Target 356/424: target_355 ---
# Target target_355 | Avg RMSE: 0.0401 (+/- 0.0000)
#
# --- Processing Target 357/424: target_356 ---
# Target target_356 | Avg RMSE: 0.0337 (+/- 0.0000)
#
# --- Processing Target 358/424: target_357 ---
# Target target_357 | Avg RMSE: 0.0562 (+/- 0.0000)
#
# --- Processing Target 359/424: target_358 ---
# Target target_358 | Avg RMSE: 0.0309 (+/- 0.0000)
#
# --- Processing Target 360/424: target_359 ---
# Target target_359 | Avg RMSE: 0.0252 (+/- 0.0000)
#
# --- Processing Target 361/424: target_360 ---
# Target target_360 | Avg RMSE: 0.0243 (+/- 0.0000)
#
# --- Processing Target 362/424: target_361 ---
# Target target_361 | Avg RMSE: 0.0522 (+/- 0.0000)
#
# --- Processing Target 363/424: target_362 ---
# Target target_362 | Avg RMSE: 0.0505 (+/- 0.0000)
#
# --- Processing Target 364/424: target_363 ---
# Target target_363 | Avg RMSE: 0.0205 (+/- 0.0000)
#
# --- Processing Target 365/424: target_364 ---
# Target target_364 | Avg RMSE: 0.0474 (+/- 0.0000)
#
# --- Processing Target 366/424: target_365 ---
# Target target_365 | Avg RMSE: 0.0377 (+/- 0.0000)
#
# --- Processing Target 367/424: target_366 ---
# Target target_366 | Avg RMSE: 0.0365 (+/- 0.0000)
#
# --- Processing Target 368/424: target_367 ---
# Target target_367 | Avg RMSE: 0.0189 (+/- 0.0000)
#
# --- Processing Target 369/424: target_368 ---
# Target target_368 | Avg RMSE: 0.0217 (+/- 0.0000)
#
# --- Processing Target 370/424: target_369 ---
# Target target_369 | Avg RMSE: 0.0421 (+/- 0.0000)
#
# --- Processing Target 371/424: target_370 ---
# Target target_370 | Avg RMSE: 0.0264 (+/- 0.0000)
#
# --- Processing Target 372/424: target_371 ---
# Target target_371 | Avg RMSE: 0.0202 (+/- 0.0000)
#
# --- Processing Target 373/424: target_372 ---
# Target target_372 | Avg RMSE: 0.0193 (+/- 0.0000)
#
# --- Processing Target 374/424: target_373 ---
# Target target_373 | Avg RMSE: 0.0389 (+/- 0.0000)
#
# --- Processing Target 375/424: target_374 ---
# Target target_374 | Avg RMSE: 0.0280 (+/- 0.0000)
#
# --- Processing Target 376/424: target_375 ---
# Target target_375 | Avg RMSE: 0.0275 (+/- 0.0000)
#
# --- Processing Target 377/424: target_376 ---
# Target target_376 | Avg RMSE: 0.0208 (+/- 0.0000)
#
# --- Processing Target 378/424: target_377 ---
# Target target_377 | Avg RMSE: 0.0221 (+/- 0.0000)
#
# --- Processing Target 379/424: target_378 ---
# Target target_378 | Avg RMSE: 0.0459 (+/- 0.0000)
#
# --- Processing Target 380/424: target_379 ---
# Target target_379 | Avg RMSE: 0.0220 (+/- 0.0000)
#
# --- Processing Target 381/424: target_380 ---
# Target target_380 | Avg RMSE: 0.0239 (+/- 0.0000)
#
# --- Processing Target 382/424: target_381 ---
# Target target_381 | Avg RMSE: 0.0173 (+/- 0.0000)
#
# --- Processing Target 383/424: target_382 ---
# Target target_382 | Avg RMSE: 0.0202 (+/- 0.0000)
#
# --- Processing Target 384/424: target_383 ---
# Target target_383 | Avg RMSE: 0.0281 (+/- 0.0000)
#
# --- Processing Target 385/424: target_384 ---
# Target target_384 | Avg RMSE: 0.0398 (+/- 0.0000)
#
# --- Processing Target 386/424: target_385 ---
# Target target_385 | Avg RMSE: 0.0282 (+/- 0.0000)
#
# --- Processing Target 387/424: target_386 ---
# Target target_386 | Avg RMSE: 0.0181 (+/- 0.0000)
#
# --- Processing Target 388/424: target_387 ---
# Target target_387 | Avg RMSE: 0.0519 (+/- 0.0000)
#
# --- Processing Target 389/424: target_388 ---
# Target target_388 | Avg RMSE: 0.0274 (+/- 0.0000)
#
# --- Processing Target 390/424: target_389 ---
# Target target_389 | Avg RMSE: 0.0196 (+/- 0.0000)
#
# --- Processing Target 391/424: target_390 ---
# Target target_390 | Avg RMSE: 0.0368 (+/- 0.0000)
#
# --- Processing Target 392/424: target_391 ---
# Target target_391 | Avg RMSE: 0.0377 (+/- 0.0000)
#
# --- Processing Target 393/424: target_392 ---
# Target target_392 | Avg RMSE: 0.0263 (+/- 0.0000)
#
# --- Processing Target 394/424: target_393 ---
# Target target_393 | Avg RMSE: 0.0733 (+/- 0.0000)
#
# --- Processing Target 395/424: target_394 ---
# Target target_394 | Avg RMSE: 0.0449 (+/- 0.0000)
#
# --- Processing Target 396/424: target_395 ---
# Target target_395 | Avg RMSE: 0.0228 (+/- 0.0000)
#
# --- Processing Target 397/424: target_396 ---
# Target target_396 | Avg RMSE: 0.0488 (+/- 0.0000)
#
# --- Processing Target 398/424: target_397 ---
# Target target_397 | Avg RMSE: 0.0311 (+/- 0.0000)
#
# --- Processing Target 399/424: target_398 ---
# Target target_398 | Avg RMSE: 0.0284 (+/- 0.0000)
#
# --- Processing Target 400/424: target_399 ---
# Target target_399 | Avg RMSE: 0.0381 (+/- 0.0000)
#
# --- Processing Target 401/424: target_400 ---
# Target target_400 | Avg RMSE: 0.0225 (+/- 0.0000)
#
# --- Processing Target 402/424: target_401 ---
# Target target_401 | Avg RMSE: 0.0280 (+/- 0.0000)
#
# --- Processing Target 403/424: target_402 ---
# Target target_402 | Avg RMSE: 0.0245 (+/- 0.0000)
#
# --- Processing Target 404/424: target_403 ---
# Target target_403 | Avg RMSE: 0.0391 (+/- 0.0000)
#
# --- Processing Target 405/424: target_404 ---
# Target target_404 | Avg RMSE: 0.0719 (+/- 0.0000)
#
# --- Processing Target 406/424: target_405 ---
# Target target_405 | Avg RMSE: 0.0194 (+/- 0.0000)
#
# --- Processing Target 407/424: target_406 ---
# Target target_406 | Avg RMSE: 0.0227 (+/- 0.0000)
#
# --- Processing Target 408/424: target_407 ---
# Target target_407 | Avg RMSE: 0.0268 (+/- 0.0000)
#
# --- Processing Target 409/424: target_408 ---
# Target target_408 | Avg RMSE: 0.0197 (+/- 0.0000)
#
# --- Processing Target 410/424: target_409 ---
# Target target_409 | Avg RMSE: 0.0182 (+/- 0.0000)
#
# --- Processing Target 411/424: target_410 ---
# Target target_410 | Avg RMSE: 0.0248 (+/- 0.0000)
#
# --- Processing Target 412/424: target_411 ---
# Target target_411 | Avg RMSE: 0.0565 (+/- 0.0000)
#
# --- Processing Target 413/424: target_412 ---
# Target target_412 | Avg RMSE: 0.0475 (+/- 0.0000)
#
# --- Processing Target 414/424: target_413 ---
# Target target_413 | Avg RMSE: 0.0291 (+/- 0.0000)
#
# --- Processing Target 415/424: target_414 ---
# Target target_414 | Avg RMSE: 0.0259 (+/- 0.0000)
#
# --- Processing Target 416/424: target_415 ---
# Target target_415 | Avg RMSE: 0.0196 (+/- 0.0000)
#
# --- Processing Target 417/424: target_416 ---
# Target target_416 | Avg RMSE: 0.0272 (+/- 0.0000)
#
# --- Processing Target 418/424: target_417 ---
# Target target_417 | Avg RMSE: 0.0270 (+/- 0.0000)
#
# --- Processing Target 419/424: target_418 ---
# Target target_418 | Avg RMSE: 0.0247 (+/- 0.0000)
#
# --- Processing Target 420/424: target_419 ---
# Target target_419 | Avg RMSE: 0.0221 (+/- 0.0000)
#
# --- Processing Target 421/424: target_420 ---
# Target target_420 | Avg RMSE: 0.0307 (+/- 0.0000)
#
# --- Processing Target 422/424: target_421 ---
# Target target_421 | Avg RMSE: 0.0339 (+/- 0.0000)
#
# --- Processing Target 423/424: target_422 ---
# Target target_422 | Avg RMSE: 0.0192 (+/- 0.0000)
#
# --- Processing Target 424/424: target_423 ---
# Target target_423 | Avg RMSE: 0.0484 (+/- 0.0000)
#
# --- 全ターゲットの学習が完了しました ---
#
# 平均評価スコア:
#      target  avg_rmse  std_rmse
# 0  target_0  0.014919       0.0
# 1  target_1  0.017525       0.0
# 2  target_2  0.011084       0.0
# 3  target_3  0.009637       0.0
# 4  target_4  0.014831       0.0
#
# 全ターゲットの平均RMSE: 0.0269
#
# 特徴量重要度 (上位10件):
# Precious_Metals_Momentum_5d                      8.969340
# LME_PB_Close_Return_1d                           8.896226
# LME_PB_Close_STD_5                               8.735849
# LME_ZS_Close_STD_5                               8.318396
# FX_Momentum_5d                                   8.073113
# Metals_Momentum_5d                               8.061321
# JPX_Platinum_Standard_Futures_Close_Return_1d    7.747642
# LME_AH_Close_STD_5                               7.683962
# FX_EURUSD_STD_10                                 7.549528
# Metals_Volatility_5d                             7.466981
# dtype: float64
#
# 予測結果、スコア、特徴量重要度をCSVファイルとして保存しました。
