# %% [markdown]
# <a href="https://colab.research.google.com/github/nagasora/MITSUI-CO.-Commodity-Prediction-Metric/blob/main/level1_XGBoost_model_ver1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import json
f = open("/content/drive/MyDrive/kaggle notebook/kaggle.json")
json_data = json.load(f)
os.environ['KAGGLE_USERNAME'] = json_data['username']
os.environ['KAGGLE_KEY'] = json_data['key']

# %%
#APIコマンドを入力
# !kaggle competitions download -c mitsui-commodity-prediction-challenge
# Out:
# Downloading mitsui-commodity-prediction-challenge.zip to /content
#   0% 0.00/9.94M [00:00<?, ?B/s]
# 100% 9.94M/9.94M [00:00<00:00, 1.11GB/s]

# %%
import os
import zipfile

# Specify the path to the zip file in Google Drive
zip_file_path = "/content/mitsui-commodity-prediction-challenge.zip"

# Specify the destination directory (same as the zip file directory)
destination_directory = os.path.dirname(zip_file_path)

# Create the destination directory if it doesn't exist
os.makedirs(destination_directory, exist_ok=True)

# Unzip the file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(destination_directory)

print(f"File unzipped to: {destination_directory}")
# Out:
# File unzipped to: /content

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

train = pd.read_csv('/content/train.csv')
train_labels = pd.read_csv('/content/train_labels.csv')
target_pairs = pd.read_csv('/content/target_pairs.csv')

print('training data:', train.shape)
print('train label:', train_labels.shape)
print('target_pairs:', target_pairs.shape)
# Out:
# training data: (1917, 558)
# train label: (1917, 425)
# target_pairs: (424, 3)

# %%
# ===================================================================
# 1. セットアップとデータ読み込み
# ===================================================================
import os
import gc
import pickle
import warnings
import numpy as np
import pandas as pd
import tensorflow as tf
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout, Input
from tensorflow.keras.callbacks import EarlyStopping

# --- データパス ---
TRAIN_PATH = '/content/train.csv'
LABELS_PATH = '/content/train_labels.csv'
TARGET_PAIRS_PATH = '/content/target_pairs.csv'
OOF_PREDS_PATH = '/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/oof_predictions_lgbm.csv' # ベースライン予測

# 保存用ディレクトリ
MODEL_DIR = '/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/lstm_models_masked_ver1'
SCALER_DIR = '/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/scalers_masked_ver1'
os.makedirs(MODEL_DIR, exist_ok=True)
os.makedirs(SCALER_DIR, exist_ok=True)

# --- データを読み込み、結合する ---
print("データの読み込みを開始します...")
train_df = pd.read_csv(TRAIN_PATH)
labels_df = pd.read_csv(LABELS_PATH)
target_pairs_df = pd.read_csv(TARGET_PAIRS_PATH)
featured_df = pd.merge(train_df, labels_df, on='date_id', how='left')
print("データの読み込みと結合が完了しました。")

# ===================================================================
# 2. 特徴量エンジニアリング（強化版）
# ===================================================================
print("\n特徴量エンジニアリングを開始します...")

# --- 基本的なテクニカル指標 ---
# (ユーザー様の `create_technical_features` と `create_cross_asset_features` を使用)
def create_technical_features(df, price_cols, window_sizes=[5, 10, 20]):
    """テクニカル指標を生成する"""
    features = df.copy()
    for col in price_cols:
        if col in df.columns:
            for window in window_sizes:
                features[f'{col}_MA_{window}'] = features[col].rolling(window=window, min_periods=1).mean()
                features[f'{col}_STD_{window}'] = features[col].rolling(window=window, min_periods=1).std()
            features[f'{col}_Return_1d'] = features[col].pct_change(1)
            features[f'{col}_LogReturn_1d'] = np.log(features[col] / features[col].shift(1))
            ma_20 = features[col].rolling(window=20, min_periods=1).mean()
            std_20 = features[col].rolling(window=20, min_periods=1).std()
            features[f'{col}_BB_Upper'] = ma_20 + (2 * std_20)
            features[f'{col}_BB_Lower'] = ma_20 - (2 * std_20)
    return features

def create_cross_asset_features(df, asset_groups):
    """クロスアセット特徴量を生成する"""
    features = df.copy()
    for group_name, assets in asset_groups.items():
        available_assets = [asset for asset in assets if asset in df.columns]
        if len(available_assets) >= 2:
            group_returns = df[available_assets].pct_change().rolling(5).mean()
            features[f'{group_name}_Momentum_5d'] = group_returns.mean(axis=1)
            features[f'{group_name}_Volatility_5d'] = df[available_assets].pct_change().rolling(5).std().mean(axis=1)
    return features


PRICE_COLS = [col for col in train_df.columns if '_Close' in col or '_adj_close' in col or 'FX_' in col]
featured_df = create_technical_features(featured_df, PRICE_COLS)
asset_groups = {
    'Metals': [col for col in PRICE_COLS if 'LME' in col],
    'Precious_Metals': [col for col in PRICE_COLS if 'Gold' in col or 'Silver' in col or 'Platinum' in col],
    'FX': [col for col in PRICE_COLS if 'FX' in col]
}
featured_df = create_cross_asset_features(featured_df, asset_groups)

# --- スプレッド/レシオ特徴量 ---
for _, row in target_pairs_df.iterrows():
    pair = row['pair']
    if ' - ' in pair:
        asset1, asset2 = pair.split(' - ')
        if asset1 in featured_df.columns and asset2 in featured_df.columns:
            featured_df[f'SPREAD_{asset1}_{asset2}'] = featured_df[asset1] - featured_df[asset2]
            featured_df[f'RATIO_{asset1}_{asset2}'] = featured_df[asset1] / (featured_df[asset2] + 1e-6)

# --- ラグ/移動平均乖離 特徴量 ---
lags = [1, 5, 10]
windows = [5, 10, 20]
for col in PRICE_COLS:
    for lag in lags:
        featured_df[f'{col}_lag_{lag}'] = featured_df[col].shift(lag)
    for window in windows:
        ma = featured_df[col].rolling(window=window).mean()
        featured_df[f'{col}_ma_gap_{window}'] = featured_df[col] / ma

# --- OOF予測（メタ特徴量）の読み込みと結合 ---
try:
    oof_df = pd.read_csv(OOF_PREDS_PATH, index_col=0)
    oof_df.columns = [f'target_{i}' for i in range(oof_df.shape[1])]
    oof_meta_features = oof_df.add_suffix('_oof_pred')
    featured_df_with_meta = featured_df.reset_index(drop=True).merge(
        oof_meta_features.reset_index(drop=True), left_index=True, right_index=True, how='left'
    )
    print("OOF予測をメタ特徴量として追加しました。")
except FileNotFoundError:
    print("警告: OOF予測ファイルが見つかりません。メタ特徴量なしで続行します。")
    featured_df_with_meta = featured_df.copy()

# --- 最終的な前処理 ---
# 特徴量の欠損値を埋める
feature_cols_only = [col for col in featured_df_with_meta.columns if not col.startswith('target_')]
featured_df_with_meta[feature_cols_only] = featured_df_with_meta[feature_cols_only].ffill().bfill()
featured_df_with_meta.replace([np.inf, -np.inf], 0, inplace=True) # 0で埋める方が安全な場合もある

print(f"特徴量生成完了。最終的なデータ形状: {featured_df_with_meta.shape}")
gc.collect()
# Out:
# データの読み込みを開始します...
# データの読み込みと結合が完了しました。
#
# 特徴量エンジニアリングを開始します...
# OOF予測をメタ特徴量として追加しました。
# 特徴量生成完了。最終的なデータ形状: (1917, 4440)
# 0

# %%
# ===================================================================
# 3. ヘルパー関数とモデル定義
# ===================================================================

def create_dataset_with_masking(df, target_col, oof_col, feature_cols, sequence_length, batch_size):
    """ターゲットのNaNを削除せず、そのままシーケンスを生成する"""
    data = df.copy()

    current_features = feature_cols.copy()
    if oof_col in data.columns:
        current_features.append(oof_col)

    X_data = data[current_features].ffill().bfill()
    y_data = data[target_col] # NaNを含むターゲット

    scaler = StandardScaler()
    X_scaled = scaler.fit_transform(X_data)

    dataset = tf.keras.utils.timeseries_dataset_from_array(
        X_scaled, y_data,
        sequence_length=sequence_length,
        batch_size=batch_size,
        shuffle=False
    )
    return dataset, scaler

def masked_mse(y_true, y_pred):
    """y_trueがNaNである部分を無視する平均二乗誤差（MSE）"""
    mask = tf.math.is_finite(y_true)
    y_true_masked = tf.boolean_mask(y_true, mask)
    y_pred_masked = tf.boolean_mask(y_pred, mask)
    # MeanSquaredErrorクラスのインスタンスを生成して損失を計算する
    loss_fn = tf.keras.losses.MeanSquaredError()
    return loss_fn(y_true_masked, y_pred_masked)

# %%
import xgboost as xgb
from sklearn.model_selection import TimeSeriesSplit
import pandas as pd
import numpy as np
import gc

# ===================================================================
# 1. XGBoost学習・OOF予測生成
# ===================================================================

print("\n--- XGBoostモデル群の学習とOOF予測生成を開始します ---")

# --- パラメータ設定 ---
# GPUが利用可能な場合は 'gpu_hist' を、そうでなければ 'hist' を使用
# Colab ProなどではGPUが使えます
XGB_PARAMS = {
    'objective': 'reg:squarederror',
    'eval_metric': 'rmse',
    'n_estimators': 1000,
    'learning_rate': 0.05,
    'max_depth': 6,
    'subsample': 0.8,
    'colsample_bytree': 0.8,
    'tree_method': 'gpu_hist',  # GPUがない場合は 'hist' に変更
    'early_stopping_rounds': 50,
    'n_jobs': -1,
    'seed': 42
}
N_SPLITS = 5
GAP = 5
TEST_SIZE = 90

# --- ターゲットと特徴量のリスト準備 ---
target_cols = [col for col in labels_df.columns if col.startswith('target_')]
base_feature_cols = [col for col in featured_df_with_meta.columns if not col.startswith('target_') and col != 'date_id']

# --- OOF予測を保存するためのデータフレームを初期化 ---
# featured_df (OOF予測を含まない、純粋な特徴量DF) のインデックスを使用
oof_preds_xgb = pd.DataFrame(np.nan, index=featured_df.index, columns=target_cols)

# --- 特徴量とターゲットのリスト準備 ---
# LGBMと同様に、NaNでないターゲット行のみで学習
feature_cols_for_gbdt = [col for col in featured_df.columns if col != 'date_id' and not col.startswith('target_')]

for i, target_col in enumerate(target_cols):
    print(f"\n[{i+1}/{len(target_cols)}] XGBoost: ターゲット '{target_col}' の処理を開始...")
    gc.collect()

    # 1. このターゲット用の学習データを準備 (NaNを除外)
    temp_df = featured_df[[target_col] + feature_cols_for_gbdt].dropna(subset=[target_col])
    X = temp_df[feature_cols_for_gbdt]
    y = temp_df[target_col]

    if len(X) < N_SPLITS * 2: # データが少なすぎる場合はスキップ
        print("  > データが少なすぎるためスキップします。")
        continue

    # 2. TimeSeriesSplitでクロスバリデーション
    tscv = TimeSeriesSplit(n_splits=N_SPLITS, gap=GAP, test_size=TEST_SIZE)

    for fold, (train_index, val_index) in enumerate(tscv.split(X)):
        X_train, X_val = X.iloc[train_index], X.iloc[val_index]
        y_train, y_val = y.iloc[train_index], y.iloc[val_index]

        model = xgb.XGBRegressor(**XGB_PARAMS)
        model.fit(X_train, y_train,
                  eval_set=[(X_val, y_val)],
                  verbose=False)

        val_preds = model.predict(X_val)

        # OOF予測を対応するインデックスに格納
        oof_preds_xgb.loc[X_val.index, target_col] = val_preds

    # 最後のフォールドのスコアを参考として表示
    rmse = np.sqrt(mean_squared_error(y_val, val_preds))
    print(f"  > 最終FoldのRMSE: {rmse:.4f}")

# --- ループ終了後、OOF予測をCSVに保存 ---
oof_preds_xgb.to_csv('/content/drive/MyDrive/kaggle notebook/MITSUI&CO. Commodity Prediction Challenge/oof_predictions_xgb.csv')
print("\nXGBoostのOOF予測をCSVファイルとして保存しました。")
# Out:
# --- XGBoostモデル群の学習とOOF予測生成を開始します ---
#
# [1/424] XGBoost: ターゲット 'target_0' の処理を開始...
#   > 最終FoldのRMSE: 0.0148
#
# [2/424] XGBoost: ターゲット 'target_1' の処理を開始...
#   > 最終FoldのRMSE: 0.0180
#
# [3/424] XGBoost: ターゲット 'target_2' の処理を開始...
#   > 最終FoldのRMSE: 0.0115
#
# [4/424] XGBoost: ターゲット 'target_3' の処理を開始...
#   > 最終FoldのRMSE: 0.0099
#
# [5/424] XGBoost: ターゲット 'target_4' の処理を開始...
#   > 最終FoldのRMSE: 0.0149
#
# [6/424] XGBoost: ターゲット 'target_5' の処理を開始...
#   > 最終FoldのRMSE: 0.0156
#
# [7/424] XGBoost: ターゲット 'target_6' の処理を開始...
#   > 最終FoldのRMSE: 0.0118
#
# [8/424] XGBoost: ターゲット 'target_7' の処理を開始...
#   > 最終FoldのRMSE: 0.0173
#
# [9/424] XGBoost: ターゲット 'target_8' の処理を開始...
#   > 最終FoldのRMSE: 0.0174
#
# [10/424] XGBoost: ターゲット 'target_9' の処理を開始...
#   > 最終FoldのRMSE: 0.0142
#
# [11/424] XGBoost: ターゲット 'target_10' の処理を開始...
#   > 最終FoldのRMSE: 0.0130
#
# [12/424] XGBoost: ターゲット 'target_11' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [13/424] XGBoost: ターゲット 'target_12' の処理を開始...
#   > 最終FoldのRMSE: 0.0154
#
# [14/424] XGBoost: ターゲット 'target_13' の処理を開始...
#   > 最終FoldのRMSE: 0.0149
#
# [15/424] XGBoost: ターゲット 'target_14' の処理を開始...
#   > 最終FoldのRMSE: 0.0137
#
# [16/424] XGBoost: ターゲット 'target_15' の処理を開始...
#   > 最終FoldのRMSE: 0.0130
#
# [17/424] XGBoost: ターゲット 'target_16' の処理を開始...
#   > 最終FoldのRMSE: 0.0172
#
# [18/424] XGBoost: ターゲット 'target_17' の処理を開始...
#   > 最終FoldのRMSE: 0.0320
#
# [19/424] XGBoost: ターゲット 'target_18' の処理を開始...
#   > 最終FoldのRMSE: 0.0118
#
# [20/424] XGBoost: ターゲット 'target_19' の処理を開始...
#   > 最終FoldのRMSE: 0.0147
#
# [21/424] XGBoost: ターゲット 'target_20' の処理を開始...
#   > 最終FoldのRMSE: 0.0144
#
# [22/424] XGBoost: ターゲット 'target_21' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [23/424] XGBoost: ターゲット 'target_22' の処理を開始...
#   > 最終FoldのRMSE: 0.0307
#
# [24/424] XGBoost: ターゲット 'target_23' の処理を開始...
#   > 最終FoldのRMSE: 0.0136
#
# [25/424] XGBoost: ターゲット 'target_24' の処理を開始...
#   > 最終FoldのRMSE: 0.0313
#
# [26/424] XGBoost: ターゲット 'target_25' の処理を開始...
#   > 最終FoldのRMSE: 0.0158
#
# [27/424] XGBoost: ターゲット 'target_26' の処理を開始...
#   > 最終FoldのRMSE: 0.0156
#
# [28/424] XGBoost: ターゲット 'target_27' の処理を開始...
#   > 最終FoldのRMSE: 0.0267
#
# [29/424] XGBoost: ターゲット 'target_28' の処理を開始...
#   > 最終FoldのRMSE: 0.0227
#
# [30/424] XGBoost: ターゲット 'target_29' の処理を開始...
#   > 最終FoldのRMSE: 0.0123
#
# [31/424] XGBoost: ターゲット 'target_30' の処理を開始...
#   > 最終FoldのRMSE: 0.0357
#
# [32/424] XGBoost: ターゲット 'target_31' の処理を開始...
#   > 最終FoldのRMSE: 0.0175
#
# [33/424] XGBoost: ターゲット 'target_32' の処理を開始...
#   > 最終FoldのRMSE: 0.0347
#
# [34/424] XGBoost: ターゲット 'target_33' の処理を開始...
#   > 最終FoldのRMSE: 0.0209
#
# [35/424] XGBoost: ターゲット 'target_34' の処理を開始...
#   > 最終FoldのRMSE: 0.0123
#
# [36/424] XGBoost: ターゲット 'target_35' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [37/424] XGBoost: ターゲット 'target_36' の処理を開始...
#   > 最終FoldのRMSE: 0.0115
#
# [38/424] XGBoost: ターゲット 'target_37' の処理を開始...
#   > 最終FoldのRMSE: 0.0147
#
# [39/424] XGBoost: ターゲット 'target_38' の処理を開始...
#   > 最終FoldのRMSE: 0.0196
#
# [40/424] XGBoost: ターゲット 'target_39' の処理を開始...
#   > 最終FoldのRMSE: 0.0121
#
# [41/424] XGBoost: ターゲット 'target_40' の処理を開始...
#   > 最終FoldのRMSE: 0.0386
#
# [42/424] XGBoost: ターゲット 'target_41' の処理を開始...
#   > 最終FoldのRMSE: 0.0316
#
# [43/424] XGBoost: ターゲット 'target_42' の処理を開始...
#   > 最終FoldのRMSE: 0.0383
#
# [44/424] XGBoost: ターゲット 'target_43' の処理を開始...
#   > 最終FoldのRMSE: 0.0121
#
# [45/424] XGBoost: ターゲット 'target_44' の処理を開始...
#   > 最終FoldのRMSE: 0.0115
#
# [46/424] XGBoost: ターゲット 'target_45' の処理を開始...
#   > 最終FoldのRMSE: 0.0129
#
# [47/424] XGBoost: ターゲット 'target_46' の処理を開始...
#   > 最終FoldのRMSE: 0.0164
#
# [48/424] XGBoost: ターゲット 'target_47' の処理を開始...
#   > 最終FoldのRMSE: 0.0232
#
# [49/424] XGBoost: ターゲット 'target_48' の処理を開始...
#   > 最終FoldのRMSE: 0.0185
#
# [50/424] XGBoost: ターゲット 'target_49' の処理を開始...
#   > 最終FoldのRMSE: 0.0284
#
# [51/424] XGBoost: ターゲット 'target_50' の処理を開始...
#   > 最終FoldのRMSE: 0.0299
#
# [52/424] XGBoost: ターゲット 'target_51' の処理を開始...
#   > 最終FoldのRMSE: 0.0262
#
# [53/424] XGBoost: ターゲット 'target_52' の処理を開始...
#   > 最終FoldのRMSE: 0.0255
#
# [54/424] XGBoost: ターゲット 'target_53' の処理を開始...
#   > 最終FoldのRMSE: 0.0233
#
# [55/424] XGBoost: ターゲット 'target_54' の処理を開始...
#   > 最終FoldのRMSE: 0.0132
#
# [56/424] XGBoost: ターゲット 'target_55' の処理を開始...
#   > 最終FoldのRMSE: 0.0278
#
# [57/424] XGBoost: ターゲット 'target_56' の処理を開始...
#   > 最終FoldのRMSE: 0.0136
#
# [58/424] XGBoost: ターゲット 'target_57' の処理を開始...
#   > 最終FoldのRMSE: 0.0133
#
# [59/424] XGBoost: ターゲット 'target_58' の処理を開始...
#   > 最終FoldのRMSE: 0.0159
#
# [60/424] XGBoost: ターゲット 'target_59' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [61/424] XGBoost: ターゲット 'target_60' の処理を開始...
#   > 最終FoldのRMSE: 0.0128
#
# [62/424] XGBoost: ターゲット 'target_61' の処理を開始...
#   > 最終FoldのRMSE: 0.0118
#
# [63/424] XGBoost: ターゲット 'target_62' の処理を開始...
#   > 最終FoldのRMSE: 0.0258
#
# [64/424] XGBoost: ターゲット 'target_63' の処理を開始...
#   > 最終FoldのRMSE: 0.0303
#
# [65/424] XGBoost: ターゲット 'target_64' の処理を開始...
#   > 最終FoldのRMSE: 0.0141
#
# [66/424] XGBoost: ターゲット 'target_65' の処理を開始...
#   > 最終FoldのRMSE: 0.0306
#
# [67/424] XGBoost: ターゲット 'target_66' の処理を開始...
#   > 最終FoldのRMSE: 0.0200
#
# [68/424] XGBoost: ターゲット 'target_67' の処理を開始...
#   > 最終FoldのRMSE: 0.0346
#
# [69/424] XGBoost: ターゲット 'target_68' の処理を開始...
#   > 最終FoldのRMSE: 0.0115
#
# [70/424] XGBoost: ターゲット 'target_69' の処理を開始...
#   > 最終FoldのRMSE: 0.0130
#
# [71/424] XGBoost: ターゲット 'target_70' の処理を開始...
#   > 最終FoldのRMSE: 0.0150
#
# [72/424] XGBoost: ターゲット 'target_71' の処理を開始...
#   > 最終FoldのRMSE: 0.0137
#
# [73/424] XGBoost: ターゲット 'target_72' の処理を開始...
#   > 最終FoldのRMSE: 0.0143
#
# [74/424] XGBoost: ターゲット 'target_73' の処理を開始...
#   > 最終FoldのRMSE: 0.0172
#
# [75/424] XGBoost: ターゲット 'target_74' の処理を開始...
#   > 最終FoldのRMSE: 0.0149
#
# [76/424] XGBoost: ターゲット 'target_75' の処理を開始...
#   > 最終FoldのRMSE: 0.0191
#
# [77/424] XGBoost: ターゲット 'target_76' の処理を開始...
#   > 最終FoldのRMSE: 0.0133
#
# [78/424] XGBoost: ターゲット 'target_77' の処理を開始...
#   > 最終FoldのRMSE: 0.0205
#
# [79/424] XGBoost: ターゲット 'target_78' の処理を開始...
#   > 最終FoldのRMSE: 0.0559
#
# [80/424] XGBoost: ターゲット 'target_79' の処理を開始...
#   > 最終FoldのRMSE: 0.0358
#
# [81/424] XGBoost: ターゲット 'target_80' の処理を開始...
#   > 最終FoldのRMSE: 0.0196
#
# [82/424] XGBoost: ターゲット 'target_81' の処理を開始...
#   > 最終FoldのRMSE: 0.0116
#
# [83/424] XGBoost: ターゲット 'target_82' の処理を開始...
#   > 最終FoldのRMSE: 0.0395
#
# [84/424] XGBoost: ターゲット 'target_83' の処理を開始...
#   > 最終FoldのRMSE: 0.0312
#
# [85/424] XGBoost: ターゲット 'target_84' の処理を開始...
#   > 最終FoldのRMSE: 0.0154
#
# [86/424] XGBoost: ターゲット 'target_85' の処理を開始...
#   > 最終FoldのRMSE: 0.0340
#
# [87/424] XGBoost: ターゲット 'target_86' の処理を開始...
#   > 最終FoldのRMSE: 0.0113
#
# [88/424] XGBoost: ターゲット 'target_87' の処理を開始...
#   > 最終FoldのRMSE: 0.0142
#
# [89/424] XGBoost: ターゲット 'target_88' の処理を開始...
#   > 最終FoldのRMSE: 0.0272
#
# [90/424] XGBoost: ターゲット 'target_89' の処理を開始...
#   > 最終FoldのRMSE: 0.0126
#
# [91/424] XGBoost: ターゲット 'target_90' の処理を開始...
#   > 最終FoldのRMSE: 0.0286
#
# [92/424] XGBoost: ターゲット 'target_91' の処理を開始...
#   > 最終FoldのRMSE: 0.0275
#
# [93/424] XGBoost: ターゲット 'target_92' の処理を開始...
#   > 最終FoldのRMSE: 0.0177
#
# [94/424] XGBoost: ターゲット 'target_93' の処理を開始...
#   > 最終FoldのRMSE: 0.0210
#
# [95/424] XGBoost: ターゲット 'target_94' の処理を開始...
#   > 最終FoldのRMSE: 0.0168
#
# [96/424] XGBoost: ターゲット 'target_95' の処理を開始...
#   > 最終FoldのRMSE: 0.0288
#
# [97/424] XGBoost: ターゲット 'target_96' の処理を開始...
#   > 最終FoldのRMSE: 0.0224
#
# [98/424] XGBoost: ターゲット 'target_97' の処理を開始...
#   > 最終FoldのRMSE: 0.0214
#
# [99/424] XGBoost: ターゲット 'target_98' の処理を開始...
#   > 最終FoldのRMSE: 0.0197
#
# [100/424] XGBoost: ターゲット 'target_99' の処理を開始...
#   > 最終FoldのRMSE: 0.0225
#
# [101/424] XGBoost: ターゲット 'target_100' の処理を開始...
#   > 最終FoldのRMSE: 0.0258
#
# [102/424] XGBoost: ターゲット 'target_101' の処理を開始...
#   > 最終FoldのRMSE: 0.0127
#
# [103/424] XGBoost: ターゲット 'target_102' の処理を開始...
#   > 最終FoldのRMSE: 0.0142
#
# [104/424] XGBoost: ターゲット 'target_103' の処理を開始...
#   > 最終FoldのRMSE: 0.0164
#
# [105/424] XGBoost: ターゲット 'target_104' の処理を開始...
#   > 最終FoldのRMSE: 0.0244
#
# [106/424] XGBoost: ターゲット 'target_105' の処理を開始...
#   > 最終FoldのRMSE: 0.0146
#
# [107/424] XGBoost: ターゲット 'target_106' の処理を開始...
#   > 最終FoldのRMSE: 0.0197
#
# [108/424] XGBoost: ターゲット 'target_107' の処理を開始...
#   > 最終FoldのRMSE: 0.0211
#
# [109/424] XGBoost: ターゲット 'target_108' の処理を開始...
#   > 最終FoldのRMSE: 0.0153
#
# [110/424] XGBoost: ターゲット 'target_109' の処理を開始...
#   > 最終FoldのRMSE: 0.0206
#
# [111/424] XGBoost: ターゲット 'target_110' の処理を開始...
#   > 最終FoldのRMSE: 0.0201
#
# [112/424] XGBoost: ターゲット 'target_111' の処理を開始...
#   > 最終FoldのRMSE: 0.0226
#
# [113/424] XGBoost: ターゲット 'target_112' の処理を開始...
#   > 最終FoldのRMSE: 0.0178
#
# [114/424] XGBoost: ターゲット 'target_113' の処理を開始...
#   > 最終FoldのRMSE: 0.0143
#
# [115/424] XGBoost: ターゲット 'target_114' の処理を開始...
#   > 最終FoldのRMSE: 0.0143
#
# [116/424] XGBoost: ターゲット 'target_115' の処理を開始...
#   > 最終FoldのRMSE: 0.0180
#
# [117/424] XGBoost: ターゲット 'target_116' の処理を開始...
#   > 最終FoldのRMSE: 0.0216
#
# [118/424] XGBoost: ターゲット 'target_117' の処理を開始...
#   > 最終FoldのRMSE: 0.0196
#
# [119/424] XGBoost: ターゲット 'target_118' の処理を開始...
#   > 最終FoldのRMSE: 0.0212
#
# [120/424] XGBoost: ターゲット 'target_119' の処理を開始...
#   > 最終FoldのRMSE: 0.0210
#
# [121/424] XGBoost: ターゲット 'target_120' の処理を開始...
#   > 最終FoldのRMSE: 0.0158
#
# [122/424] XGBoost: ターゲット 'target_121' の処理を開始...
#   > 最終FoldのRMSE: 0.0314
#
# [123/424] XGBoost: ターゲット 'target_122' の処理を開始...
#   > 最終FoldのRMSE: 0.0223
#
# [124/424] XGBoost: ターゲット 'target_123' の処理を開始...
#   > 最終FoldのRMSE: 0.0250
#
# [125/424] XGBoost: ターゲット 'target_124' の処理を開始...
#   > 最終FoldのRMSE: 0.0330
#
# [126/424] XGBoost: ターゲット 'target_125' の処理を開始...
#   > 最終FoldのRMSE: 0.0240
#
# [127/424] XGBoost: ターゲット 'target_126' の処理を開始...
#   > 最終FoldのRMSE: 0.0277
#
# [128/424] XGBoost: ターゲット 'target_127' の処理を開始...
#   > 最終FoldのRMSE: 0.0184
#
# [129/424] XGBoost: ターゲット 'target_128' の処理を開始...
#   > 最終FoldのRMSE: 0.0230
#
# [130/424] XGBoost: ターゲット 'target_129' の処理を開始...
#   > 最終FoldのRMSE: 0.0164
#
# [131/424] XGBoost: ターゲット 'target_130' の処理を開始...
#   > 最終FoldのRMSE: 0.0368
#
# [132/424] XGBoost: ターゲット 'target_131' の処理を開始...
#   > 最終FoldのRMSE: 0.0209
#
# [133/424] XGBoost: ターゲット 'target_132' の処理を開始...
#   > 最終FoldのRMSE: 0.0259
#
# [134/424] XGBoost: ターゲット 'target_133' の処理を開始...
#   > 最終FoldのRMSE: 0.0168
#
# [135/424] XGBoost: ターゲット 'target_134' の処理を開始...
#   > 最終FoldのRMSE: 0.0185
#
# [136/424] XGBoost: ターゲット 'target_135' の処理を開始...
#   > 最終FoldのRMSE: 0.0384
#
# [137/424] XGBoost: ターゲット 'target_136' の処理を開始...
#   > 最終FoldのRMSE: 0.0206
#
# [138/424] XGBoost: ターゲット 'target_137' の処理を開始...
#   > 最終FoldのRMSE: 0.0217
#
# [139/424] XGBoost: ターゲット 'target_138' の処理を開始...
#   > 最終FoldのRMSE: 0.0156
#
# [140/424] XGBoost: ターゲット 'target_139' の処理を開始...
#   > 最終FoldのRMSE: 0.0454
#
# [141/424] XGBoost: ターゲット 'target_140' の処理を開始...
#   > 最終FoldのRMSE: 0.0447
#
# [142/424] XGBoost: ターゲット 'target_141' の処理を開始...
#   > 最終FoldのRMSE: 0.0150
#
# [143/424] XGBoost: ターゲット 'target_142' の処理を開始...
#   > 最終FoldのRMSE: 0.0388
#
# [144/424] XGBoost: ターゲット 'target_143' の処理を開始...
#   > 最終FoldのRMSE: 0.0367
#
# [145/424] XGBoost: ターゲット 'target_144' の処理を開始...
#   > 最終FoldのRMSE: 0.0321
#
# [146/424] XGBoost: ターゲット 'target_145' の処理を開始...
#   > 最終FoldのRMSE: 0.0193
#
# [147/424] XGBoost: ターゲット 'target_146' の処理を開始...
#   > 最終FoldのRMSE: 0.0293
#
# [148/424] XGBoost: ターゲット 'target_147' の処理を開始...
#   > 最終FoldのRMSE: 0.0492
#
# [149/424] XGBoost: ターゲット 'target_148' の処理を開始...
#   > 最終FoldのRMSE: 0.0189
#
# [150/424] XGBoost: ターゲット 'target_149' の処理を開始...
#   > 最終FoldのRMSE: 0.0299
#
# [151/424] XGBoost: ターゲット 'target_150' の処理を開始...
#   > 最終FoldのRMSE: 0.0353
#
# [152/424] XGBoost: ターゲット 'target_151' の処理を開始...
#   > 最終FoldのRMSE: 0.0212
#
# [153/424] XGBoost: ターゲット 'target_152' の処理を開始...
#   > 最終FoldのRMSE: 0.0193
#
# [154/424] XGBoost: ターゲット 'target_153' の処理を開始...
#   > 最終FoldのRMSE: 0.0159
#
# [155/424] XGBoost: ターゲット 'target_154' の処理を開始...
#   > 最終FoldのRMSE: 0.0384
#
# [156/424] XGBoost: ターゲット 'target_155' の処理を開始...
#   > 最終FoldのRMSE: 0.0176
#
# [157/424] XGBoost: ターゲット 'target_156' の処理を開始...
#   > 最終FoldのRMSE: 0.0226
#
# [158/424] XGBoost: ターゲット 'target_157' の処理を開始...
#   > 最終FoldのRMSE: 0.0347
#
# [159/424] XGBoost: ターゲット 'target_158' の処理を開始...
#   > 最終FoldのRMSE: 0.0376
#
# [160/424] XGBoost: ターゲット 'target_159' の処理を開始...
#   > 最終FoldのRMSE: 0.0215
#
# [161/424] XGBoost: ターゲット 'target_160' の処理を開始...
#   > 最終FoldのRMSE: 0.0198
#
# [162/424] XGBoost: ターゲット 'target_161' の処理を開始...
#   > 最終FoldのRMSE: 0.0144
#
# [163/424] XGBoost: ターゲット 'target_162' の処理を開始...
#   > 最終FoldのRMSE: 0.0153
#
# [164/424] XGBoost: ターゲット 'target_163' の処理を開始...
#   > 最終FoldのRMSE: 0.0382
#
# [165/424] XGBoost: ターゲット 'target_164' の処理を開始...
#   > 最終FoldのRMSE: 0.0192
#
# [166/424] XGBoost: ターゲット 'target_165' の処理を開始...
#   > 最終FoldのRMSE: 0.0369
#
# [167/424] XGBoost: ターゲット 'target_166' の処理を開始...
#   > 最終FoldのRMSE: 0.0234
#
# [168/424] XGBoost: ターゲット 'target_167' の処理を開始...
#   > 最終FoldのRMSE: 0.0226
#
# [169/424] XGBoost: ターゲット 'target_168' の処理を開始...
#   > 最終FoldのRMSE: 0.0166
#
# [170/424] XGBoost: ターゲット 'target_169' の処理を開始...
#   > 最終FoldのRMSE: 0.0160
#
# [171/424] XGBoost: ターゲット 'target_170' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [172/424] XGBoost: ターゲット 'target_171' の処理を開始...
#   > 最終FoldのRMSE: 0.0188
#
# [173/424] XGBoost: ターゲット 'target_172' の処理を開始...
#   > 最終FoldのRMSE: 0.0219
#
# [174/424] XGBoost: ターゲット 'target_173' の処理を開始...
#   > 最終FoldのRMSE: 0.0498
#
# [175/424] XGBoost: ターゲット 'target_174' の処理を開始...
#   > 最終FoldのRMSE: 0.0373
#
# [176/424] XGBoost: ターゲット 'target_175' の処理を開始...
#   > 最終FoldのRMSE: 0.0214
#
# [177/424] XGBoost: ターゲット 'target_176' の処理を開始...
#   > 最終FoldのRMSE: 0.0374
#
# [178/424] XGBoost: ターゲット 'target_177' の処理を開始...
#   > 最終FoldのRMSE: 0.0171
#
# [179/424] XGBoost: ターゲット 'target_178' の処理を開始...
#   > 最終FoldのRMSE: 0.0215
#
# [180/424] XGBoost: ターゲット 'target_179' の処理を開始...
#   > 最終FoldのRMSE: 0.0227
#
# [181/424] XGBoost: ターゲット 'target_180' の処理を開始...
#   > 最終FoldのRMSE: 0.0294
#
# [182/424] XGBoost: ターゲット 'target_181' の処理を開始...
#   > 最終FoldのRMSE: 0.0429
#
# [183/424] XGBoost: ターゲット 'target_182' の処理を開始...
#   > 最終FoldのRMSE: 0.0188
#
# [184/424] XGBoost: ターゲット 'target_183' の処理を開始...
#   > 最終FoldのRMSE: 0.0406
#
# [185/424] XGBoost: ターゲット 'target_184' の処理を開始...
#   > 最終FoldのRMSE: 0.0229
#
# [186/424] XGBoost: ターゲット 'target_185' の処理を開始...
#   > 最終FoldのRMSE: 0.0323
#
# [187/424] XGBoost: ターゲット 'target_186' の処理を開始...
#   > 最終FoldのRMSE: 0.0235
#
# [188/424] XGBoost: ターゲット 'target_187' の処理を開始...
#   > 最終FoldのRMSE: 0.0174
#
# [189/424] XGBoost: ターゲット 'target_188' の処理を開始...
#   > 最終FoldのRMSE: 0.0185
#
# [190/424] XGBoost: ターゲット 'target_189' の処理を開始...
#   > 最終FoldのRMSE: 0.0203
#
# [191/424] XGBoost: ターゲット 'target_190' の処理を開始...
#   > 最終FoldのRMSE: 0.0221
#
# [192/424] XGBoost: ターゲット 'target_191' の処理を開始...
#   > 最終FoldのRMSE: 0.0267
#
# [193/424] XGBoost: ターゲット 'target_192' の処理を開始...
#   > 最終FoldのRMSE: 0.0369
#
# [194/424] XGBoost: ターゲット 'target_193' の処理を開始...
#   > 最終FoldのRMSE: 0.0646
#
# [195/424] XGBoost: ターゲット 'target_194' の処理を開始...
#   > 最終FoldのRMSE: 0.0181
#
# [196/424] XGBoost: ターゲット 'target_195' の処理を開始...
#   > 最終FoldのRMSE: 0.0515
#
# [197/424] XGBoost: ターゲット 'target_196' の処理を開始...
#   > 最終FoldのRMSE: 0.0211
#
# [198/424] XGBoost: ターゲット 'target_197' の処理を開始...
#   > 最終FoldのRMSE: 0.0171
#
# [199/424] XGBoost: ターゲット 'target_198' の処理を開始...
#   > 最終FoldのRMSE: 0.0161
#
# [200/424] XGBoost: ターゲット 'target_199' の処理を開始...
#   > 最終FoldのRMSE: 0.0344
#
# [201/424] XGBoost: ターゲット 'target_200' の処理を開始...
#   > 最終FoldのRMSE: 0.0182
#
# [202/424] XGBoost: ターゲット 'target_201' の処理を開始...
#   > 最終FoldのRMSE: 0.0332
#
# [203/424] XGBoost: ターゲット 'target_202' の処理を開始...
#   > 最終FoldのRMSE: 0.0225
#
# [204/424] XGBoost: ターゲット 'target_203' の処理を開始...
#   > 最終FoldのRMSE: 0.0304
#
# [205/424] XGBoost: ターゲット 'target_204' の処理を開始...
#   > 最終FoldのRMSE: 0.0330
#
# [206/424] XGBoost: ターゲット 'target_205' の処理を開始...
#   > 最終FoldのRMSE: 0.0208
#
# [207/424] XGBoost: ターゲット 'target_206' の処理を開始...
#   > 最終FoldのRMSE: 0.0198
#
# [208/424] XGBoost: ターゲット 'target_207' の処理を開始...
#   > 最終FoldのRMSE: 0.0239
#
# [209/424] XGBoost: ターゲット 'target_208' の処理を開始...
#   > 最終FoldのRMSE: 0.0377
#
# [210/424] XGBoost: ターゲット 'target_209' の処理を開始...
#   > 最終FoldのRMSE: 0.0456
#
# [211/424] XGBoost: ターゲット 'target_210' の処理を開始...
#   > 最終FoldのRMSE: 0.0187
#
# [212/424] XGBoost: ターゲット 'target_211' の処理を開始...
#   > 最終FoldのRMSE: 0.0192
#
# [213/424] XGBoost: ターゲット 'target_212' の処理を開始...
#   > 最終FoldのRMSE: 0.0130
#
# [214/424] XGBoost: ターゲット 'target_213' の処理を開始...
#   > 最終FoldのRMSE: 0.0146
#
# [215/424] XGBoost: ターゲット 'target_214' の処理を開始...
#   > 最終FoldのRMSE: 0.0195
#
# [216/424] XGBoost: ターゲット 'target_215' の処理を開始...
#   > 最終FoldのRMSE: 0.0221
#
# [217/424] XGBoost: ターゲット 'target_216' の処理を開始...
#   > 最終FoldのRMSE: 0.0246
#
# [218/424] XGBoost: ターゲット 'target_217' の処理を開始...
#   > 最終FoldのRMSE: 0.0255
#
# [219/424] XGBoost: ターゲット 'target_218' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [220/424] XGBoost: ターゲット 'target_219' の処理を開始...
#   > 最終FoldのRMSE: 0.0217
#
# [221/424] XGBoost: ターゲット 'target_220' の処理を開始...
#   > 最終FoldのRMSE: 0.0215
#
# [222/424] XGBoost: ターゲット 'target_221' の処理を開始...
#   > 最終FoldのRMSE: 0.0214
#
# [223/424] XGBoost: ターゲット 'target_222' の処理を開始...
#   > 最終FoldのRMSE: 0.0213
#
# [224/424] XGBoost: ターゲット 'target_223' の処理を開始...
#   > 最終FoldのRMSE: 0.0198
#
# [225/424] XGBoost: ターゲット 'target_224' の処理を開始...
#   > 最終FoldのRMSE: 0.0444
#
# [226/424] XGBoost: ターゲット 'target_225' の処理を開始...
#   > 最終FoldのRMSE: 0.0335
#
# [227/424] XGBoost: ターゲット 'target_226' の処理を開始...
#   > 最終FoldのRMSE: 0.0281
#
# [228/424] XGBoost: ターゲット 'target_227' の処理を開始...
#   > 最終FoldのRMSE: 0.0257
#
# [229/424] XGBoost: ターゲット 'target_228' の処理を開始...
#   > 最終FoldのRMSE: 0.0226
#
# [230/424] XGBoost: ターゲット 'target_229' の処理を開始...
#   > 最終FoldのRMSE: 0.0236
#
# [231/424] XGBoost: ターゲット 'target_230' の処理を開始...
#   > 最終FoldのRMSE: 0.0541
#
# [232/424] XGBoost: ターゲット 'target_231' の処理を開始...
#   > 最終FoldのRMSE: 0.0223
#
# [233/424] XGBoost: ターゲット 'target_232' の処理を開始...
#   > 最終FoldのRMSE: 0.0277
#
# [234/424] XGBoost: ターゲット 'target_233' の処理を開始...
#   > 最終FoldのRMSE: 0.0260
#
# [235/424] XGBoost: ターゲット 'target_234' の処理を開始...
#   > 最終FoldのRMSE: 0.0214
#
# [236/424] XGBoost: ターゲット 'target_235' の処理を開始...
#   > 最終FoldのRMSE: 0.0502
#
# [237/424] XGBoost: ターゲット 'target_236' の処理を開始...
#   > 最終FoldのRMSE: 0.0205
#
# [238/424] XGBoost: ターゲット 'target_237' の処理を開始...
#   > 最終FoldのRMSE: 0.0434
#
# [239/424] XGBoost: ターゲット 'target_238' の処理を開始...
#   > 最終FoldのRMSE: 0.0248
#
# [240/424] XGBoost: ターゲット 'target_239' の処理を開始...
#   > 最終FoldのRMSE: 0.0193
#
# [241/424] XGBoost: ターゲット 'target_240' の処理を開始...
#   > 最終FoldのRMSE: 0.0186
#
# [242/424] XGBoost: ターゲット 'target_241' の処理を開始...
#   > 最終FoldのRMSE: 0.0635
#
# [243/424] XGBoost: ターゲット 'target_242' の処理を開始...
#   > 最終FoldのRMSE: 0.0285
#
# [244/424] XGBoost: ターゲット 'target_243' の処理を開始...
#   > 最終FoldのRMSE: 0.0232
#
# [245/424] XGBoost: ターゲット 'target_244' の処理を開始...
#   > 最終FoldのRMSE: 0.0542
#
# [246/424] XGBoost: ターゲット 'target_245' の処理を開始...
#   > 最終FoldのRMSE: 0.0262
#
# [247/424] XGBoost: ターゲット 'target_246' の処理を開始...
#   > 最終FoldのRMSE: 0.0396
#
# [248/424] XGBoost: ターゲット 'target_247' の処理を開始...
#   > 最終FoldのRMSE: 0.0496
#
# [249/424] XGBoost: ターゲット 'target_248' の処理を開始...
#   > 最終FoldのRMSE: 0.0492
#
# [250/424] XGBoost: ターゲット 'target_249' の処理を開始...
#   > 最終FoldのRMSE: 0.0294
#
# [251/424] XGBoost: ターゲット 'target_250' の処理を開始...
#   > 最終FoldのRMSE: 0.0162
#
# [252/424] XGBoost: ターゲット 'target_251' の処理を開始...
#   > 最終FoldのRMSE: 0.0245
#
# [253/424] XGBoost: ターゲット 'target_252' の処理を開始...
#   > 最終FoldのRMSE: 0.0487
#
# [254/424] XGBoost: ターゲット 'target_253' の処理を開始...
#   > 最終FoldのRMSE: 0.0246
#
# [255/424] XGBoost: ターゲット 'target_254' の処理を開始...
#   > 最終FoldのRMSE: 0.0225
#
# [256/424] XGBoost: ターゲット 'target_255' の処理を開始...
#   > 最終FoldのRMSE: 0.0372
#
# [257/424] XGBoost: ターゲット 'target_256' の処理を開始...
#   > 最終FoldのRMSE: 0.0269
#
# [258/424] XGBoost: ターゲット 'target_257' の処理を開始...
#   > 最終FoldのRMSE: 0.0469
#
# [259/424] XGBoost: ターゲット 'target_258' の処理を開始...
#   > 最終FoldのRMSE: 0.0229
#
# [260/424] XGBoost: ターゲット 'target_259' の処理を開始...
#   > 最終FoldのRMSE: 0.0247
#
# [261/424] XGBoost: ターゲット 'target_260' の処理を開始...
#   > 最終FoldのRMSE: 0.0186
#
# [262/424] XGBoost: ターゲット 'target_261' の処理を開始...
#   > 最終FoldのRMSE: 0.0598
#
# [263/424] XGBoost: ターゲット 'target_262' の処理を開始...
#   > 最終FoldのRMSE: 0.0209
#
# [264/424] XGBoost: ターゲット 'target_263' の処理を開始...
#   > 最終FoldのRMSE: 0.0395
#
# [265/424] XGBoost: ターゲット 'target_264' の処理を開始...
#   > 最終FoldのRMSE: 0.0217
#
# [266/424] XGBoost: ターゲット 'target_265' の処理を開始...
#   > 最終FoldのRMSE: 0.0240
#
# [267/424] XGBoost: ターゲット 'target_266' の処理を開始...
#   > 最終FoldのRMSE: 0.0497
#
# [268/424] XGBoost: ターゲット 'target_267' の処理を開始...
#   > 最終FoldのRMSE: 0.0698
#
# [269/424] XGBoost: ターゲット 'target_268' の処理を開始...
#   > 最終FoldのRMSE: 0.0171
#
# [270/424] XGBoost: ターゲット 'target_269' の処理を開始...
#   > 最終FoldのRMSE: 0.0390
#
# [271/424] XGBoost: ターゲット 'target_270' の処理を開始...
#   > 最終FoldのRMSE: 0.0215
#
# [272/424] XGBoost: ターゲット 'target_271' の処理を開始...
#   > 最終FoldのRMSE: 0.0261
#
# [273/424] XGBoost: ターゲット 'target_272' の処理を開始...
#   > 最終FoldのRMSE: 0.0408
#
# [274/424] XGBoost: ターゲット 'target_273' の処理を開始...
#   > 最終FoldのRMSE: 0.0292
#
# [275/424] XGBoost: ターゲット 'target_274' の処理を開始...
#   > 最終FoldのRMSE: 0.0162
#
# [276/424] XGBoost: ターゲット 'target_275' の処理を開始...
#   > 最終FoldのRMSE: 0.0227
#
# [277/424] XGBoost: ターゲット 'target_276' の処理を開始...
#   > 最終FoldのRMSE: 0.0543
#
# [278/424] XGBoost: ターゲット 'target_277' の処理を開始...
#   > 最終FoldのRMSE: 0.0189
#
# [279/424] XGBoost: ターゲット 'target_278' の処理を開始...
#   > 最終FoldのRMSE: 0.0441
#
# [280/424] XGBoost: ターゲット 'target_279' の処理を開始...
#   > 最終FoldのRMSE: 0.0222
#
# [281/424] XGBoost: ターゲット 'target_280' の処理を開始...
#   > 最終FoldのRMSE: 0.0212
#
# [282/424] XGBoost: ターゲット 'target_281' の処理を開始...
#   > 最終FoldのRMSE: 0.0197
#
# [283/424] XGBoost: ターゲット 'target_282' の処理を開始...
#   > 最終FoldのRMSE: 0.0331
#
# [284/424] XGBoost: ターゲット 'target_283' の処理を開始...
#   > 最終FoldのRMSE: 0.0210
#
# [285/424] XGBoost: ターゲット 'target_284' の処理を開始...
#   > 最終FoldのRMSE: 0.0212
#
# [286/424] XGBoost: ターゲット 'target_285' の処理を開始...
#   > 最終FoldのRMSE: 0.0241
#
# [287/424] XGBoost: ターゲット 'target_286' の処理を開始...
#   > 最終FoldのRMSE: 0.0386
#
# [288/424] XGBoost: ターゲット 'target_287' の処理を開始...
#   > 最終FoldのRMSE: 0.0449
#
# [289/424] XGBoost: ターゲット 'target_288' の処理を開始...
#   > 最終FoldのRMSE: 0.0466
#
# [290/424] XGBoost: ターゲット 'target_289' の処理を開始...
#   > 最終FoldのRMSE: 0.0291
#
# [291/424] XGBoost: ターゲット 'target_290' の処理を開始...
#   > 最終FoldのRMSE: 0.0432
#
# [292/424] XGBoost: ターゲット 'target_291' の処理を開始...
#   > 最終FoldのRMSE: 0.0248
#
# [293/424] XGBoost: ターゲット 'target_292' の処理を開始...
#   > 最終FoldのRMSE: 0.0209
#
# [294/424] XGBoost: ターゲット 'target_293' の処理を開始...
#   > 最終FoldのRMSE: 0.0333
#
# [295/424] XGBoost: ターゲット 'target_294' の処理を開始...
#   > 最終FoldのRMSE: 0.0192
#
# [296/424] XGBoost: ターゲット 'target_295' の処理を開始...
#   > 最終FoldのRMSE: 0.0171
#
# [297/424] XGBoost: ターゲット 'target_296' の処理を開始...
#   > 最終FoldのRMSE: 0.0335
#
# [298/424] XGBoost: ターゲット 'target_297' の処理を開始...
#   > 最終FoldのRMSE: 0.0373
#
# [299/424] XGBoost: ターゲット 'target_298' の処理を開始...
#   > 最終FoldのRMSE: 0.0264
#
# [300/424] XGBoost: ターゲット 'target_299' の処理を開始...
#   > 最終FoldのRMSE: 0.0215
#
# [301/424] XGBoost: ターゲット 'target_300' の処理を開始...
#   > 最終FoldのRMSE: 0.0459
#
# [302/424] XGBoost: ターゲット 'target_301' の処理を開始...
#   > 最終FoldのRMSE: 0.0197
#
# [303/424] XGBoost: ターゲット 'target_302' の処理を開始...
#   > 最終FoldのRMSE: 0.0479
#
# [304/424] XGBoost: ターゲット 'target_303' の処理を開始...
#   > 最終FoldのRMSE: 0.0271
#
# [305/424] XGBoost: ターゲット 'target_304' の処理を開始...
#   > 最終FoldのRMSE: 0.0241
#
# [306/424] XGBoost: ターゲット 'target_305' の処理を開始...
#   > 最終FoldのRMSE: 0.0306
#
# [307/424] XGBoost: ターゲット 'target_306' の処理を開始...
#   > 最終FoldのRMSE: 0.0171
#
# [308/424] XGBoost: ターゲット 'target_307' の処理を開始...
#   > 最終FoldのRMSE: 0.0392
#
# [309/424] XGBoost: ターゲット 'target_308' の処理を開始...
#   > 最終FoldのRMSE: 0.0252
#
# [310/424] XGBoost: ターゲット 'target_309' の処理を開始...
#   > 最終FoldのRMSE: 0.0186
#
# [311/424] XGBoost: ターゲット 'target_310' の処理を開始...
#   > 最終FoldのRMSE: 0.0196
#
# [312/424] XGBoost: ターゲット 'target_311' の処理を開始...
#   > 最終FoldのRMSE: 0.0243
#
# [313/424] XGBoost: ターゲット 'target_312' の処理を開始...
#   > 最終FoldのRMSE: 0.0253
#
# [314/424] XGBoost: ターゲット 'target_313' の処理を開始...
#   > 最終FoldのRMSE: 0.0446
#
# [315/424] XGBoost: ターゲット 'target_314' の処理を開始...
#   > 最終FoldのRMSE: 0.0256
#
# [316/424] XGBoost: ターゲット 'target_315' の処理を開始...
#   > 最終FoldのRMSE: 0.0451
#
# [317/424] XGBoost: ターゲット 'target_316' の処理を開始...
#   > 最終FoldのRMSE: 0.0242
#
# [318/424] XGBoost: ターゲット 'target_317' の処理を開始...
#   > 最終FoldのRMSE: 0.0355
#
# [319/424] XGBoost: ターゲット 'target_318' の処理を開始...
#   > 最終FoldのRMSE: 0.0128
#
# [320/424] XGBoost: ターゲット 'target_319' の処理を開始...
#   > 最終FoldのRMSE: 0.0223
#
# [321/424] XGBoost: ターゲット 'target_320' の処理を開始...
#   > 最終FoldのRMSE: 0.0308
#
# [322/424] XGBoost: ターゲット 'target_321' の処理を開始...
#   > 最終FoldのRMSE: 0.0149
#
# [323/424] XGBoost: ターゲット 'target_322' の処理を開始...
#   > 最終FoldのRMSE: 0.0165
#
# [324/424] XGBoost: ターゲット 'target_323' の処理を開始...
#   > 最終FoldのRMSE: 0.0186
#
# [325/424] XGBoost: ターゲット 'target_324' の処理を開始...
#   > 最終FoldのRMSE: 0.0275
#
# [326/424] XGBoost: ターゲット 'target_325' の処理を開始...
#   > 最終FoldのRMSE: 0.0666
#
# [327/424] XGBoost: ターゲット 'target_326' の処理を開始...
#   > 最終FoldのRMSE: 0.0283
#
# [328/424] XGBoost: ターゲット 'target_327' の処理を開始...
#   > 最終FoldのRMSE: 0.0324
#
# [329/424] XGBoost: ターゲット 'target_328' の処理を開始...
#   > 最終FoldのRMSE: 0.0333
#
# [330/424] XGBoost: ターゲット 'target_329' の処理を開始...
#   > 最終FoldのRMSE: 0.0859
#
# [331/424] XGBoost: ターゲット 'target_330' の処理を開始...
#   > 最終FoldのRMSE: 0.0225
#
# [332/424] XGBoost: ターゲット 'target_331' の処理を開始...
#   > 最終FoldのRMSE: 0.0500
#
# [333/424] XGBoost: ターゲット 'target_332' の処理を開始...
#   > 最終FoldのRMSE: 0.0258
#
# [334/424] XGBoost: ターゲット 'target_333' の処理を開始...
#   > 最終FoldのRMSE: 0.0442
#
# [335/424] XGBoost: ターゲット 'target_334' の処理を開始...
#   > 最終FoldのRMSE: 0.0536
#
# [336/424] XGBoost: ターゲット 'target_335' の処理を開始...
#   > 最終FoldのRMSE: 0.0509
#
# [337/424] XGBoost: ターゲット 'target_336' の処理を開始...
#   > 最終FoldのRMSE: 0.0320
#
# [338/424] XGBoost: ターゲット 'target_337' の処理を開始...
#   > 最終FoldのRMSE: 0.0283
#
# [339/424] XGBoost: ターゲット 'target_338' の処理を開始...
#   > 最終FoldのRMSE: 0.0550
#
# [340/424] XGBoost: ターゲット 'target_339' の処理を開始...
#   > 最終FoldのRMSE: 0.0256
#
# [341/424] XGBoost: ターゲット 'target_340' の処理を開始...
#   > 最終FoldのRMSE: 0.0245
#
# [342/424] XGBoost: ターゲット 'target_341' の処理を開始...
#   > 最終FoldのRMSE: 0.0236
#
# [343/424] XGBoost: ターゲット 'target_342' の処理を開始...
#   > 最終FoldのRMSE: 0.0451
#
# [344/424] XGBoost: ターゲット 'target_343' の処理を開始...
#   > 最終FoldのRMSE: 0.0589
#
# [345/424] XGBoost: ターゲット 'target_344' の処理を開始...
#   > 最終FoldのRMSE: 0.0366
#
# [346/424] XGBoost: ターゲット 'target_345' の処理を開始...
#   > 最終FoldのRMSE: 0.0228
#
# [347/424] XGBoost: ターゲット 'target_346' の処理を開始...
#   > 最終FoldのRMSE: 0.0301
#
# [348/424] XGBoost: ターゲット 'target_347' の処理を開始...
#   > 最終FoldのRMSE: 0.0302
#
# [349/424] XGBoost: ターゲット 'target_348' の処理を開始...
#   > 最終FoldのRMSE: 0.0258
#
# [350/424] XGBoost: ターゲット 'target_349' の処理を開始...
#   > 最終FoldのRMSE: 0.0250
#
# [351/424] XGBoost: ターゲット 'target_350' の処理を開始...
#   > 最終FoldのRMSE: 0.0225
#
# [352/424] XGBoost: ターゲット 'target_351' の処理を開始...
#   > 最終FoldのRMSE: 0.0253
#
# [353/424] XGBoost: ターゲット 'target_352' の処理を開始...
#   > 最終FoldのRMSE: 0.0495
#
# [354/424] XGBoost: ターゲット 'target_353' の処理を開始...
#   > 最終FoldのRMSE: 0.0238
#
# [355/424] XGBoost: ターゲット 'target_354' の処理を開始...
#   > 最終FoldのRMSE: 0.0363
#
# [356/424] XGBoost: ターゲット 'target_355' の処理を開始...
#   > 最終FoldのRMSE: 0.0404
#
# [357/424] XGBoost: ターゲット 'target_356' の処理を開始...
#   > 最終FoldのRMSE: 0.0348
#
# [358/424] XGBoost: ターゲット 'target_357' の処理を開始...
#   > 最終FoldのRMSE: 0.0504
#
# [359/424] XGBoost: ターゲット 'target_358' の処理を開始...
#   > 最終FoldのRMSE: 0.0314
#
# [360/424] XGBoost: ターゲット 'target_359' の処理を開始...
#   > 最終FoldのRMSE: 0.0241
#
# [361/424] XGBoost: ターゲット 'target_360' の処理を開始...
#   > 最終FoldのRMSE: 0.0250
#
# [362/424] XGBoost: ターゲット 'target_361' の処理を開始...
#   > 最終FoldのRMSE: 0.0535
#
# [363/424] XGBoost: ターゲット 'target_362' の処理を開始...
#   > 最終FoldのRMSE: 0.0500
#
# [364/424] XGBoost: ターゲット 'target_363' の処理を開始...
#   > 最終FoldのRMSE: 0.0216
#
# [365/424] XGBoost: ターゲット 'target_364' の処理を開始...
#   > 最終FoldのRMSE: 0.0535
#
# [366/424] XGBoost: ターゲット 'target_365' の処理を開始...
#   > 最終FoldのRMSE: 0.0393
#
# [367/424] XGBoost: ターゲット 'target_366' の処理を開始...
#   > 最終FoldのRMSE: 0.0371
#
# [368/424] XGBoost: ターゲット 'target_367' の処理を開始...
#   > 最終FoldのRMSE: 0.0185
#
# [369/424] XGBoost: ターゲット 'target_368' の処理を開始...
#   > 最終FoldのRMSE: 0.0220
#
# [370/424] XGBoost: ターゲット 'target_369' の処理を開始...
#   > 最終FoldのRMSE: 0.0408
#
# [371/424] XGBoost: ターゲット 'target_370' の処理を開始...
#   > 最終FoldのRMSE: 0.0270
#
# [372/424] XGBoost: ターゲット 'target_371' の処理を開始...
#   > 最終FoldのRMSE: 0.0205
#
# [373/424] XGBoost: ターゲット 'target_372' の処理を開始...
#   > 最終FoldのRMSE: 0.0201
#
# [374/424] XGBoost: ターゲット 'target_373' の処理を開始...
#   > 最終FoldのRMSE: 0.0404
#
# [375/424] XGBoost: ターゲット 'target_374' の処理を開始...
#   > 最終FoldのRMSE: 0.0299
#
# [376/424] XGBoost: ターゲット 'target_375' の処理を開始...
#   > 最終FoldのRMSE: 0.0273
#
# [377/424] XGBoost: ターゲット 'target_376' の処理を開始...
#   > 最終FoldのRMSE: 0.0211
#
# [378/424] XGBoost: ターゲット 'target_377' の処理を開始...
#   > 最終FoldのRMSE: 0.0228
#
# [379/424] XGBoost: ターゲット 'target_378' の処理を開始...
#   > 最終FoldのRMSE: 0.0466
#
# [380/424] XGBoost: ターゲット 'target_379' の処理を開始...
#   > 最終FoldのRMSE: 0.0256
#
# [381/424] XGBoost: ターゲット 'target_380' の処理を開始...
#   > 最終FoldのRMSE: 0.0257
#
# [382/424] XGBoost: ターゲット 'target_381' の処理を開始...
#   > 最終FoldのRMSE: 0.0167
#
# [383/424] XGBoost: ターゲット 'target_382' の処理を開始...
#   > 最終FoldのRMSE: 0.0192
#
# [384/424] XGBoost: ターゲット 'target_383' の処理を開始...
#   > 最終FoldのRMSE: 0.0277
#
# [385/424] XGBoost: ターゲット 'target_384' の処理を開始...
#   > 最終FoldのRMSE: 0.0412
#
# [386/424] XGBoost: ターゲット 'target_385' の処理を開始...
#   > 最終FoldのRMSE: 0.0282
#
# [387/424] XGBoost: ターゲット 'target_386' の処理を開始...
#   > 最終FoldのRMSE: 0.0195
#
# [388/424] XGBoost: ターゲット 'target_387' の処理を開始...
#   > 最終FoldのRMSE: 0.0504
#
# [389/424] XGBoost: ターゲット 'target_388' の処理を開始...
#   > 最終FoldのRMSE: 0.0262
#
# [390/424] XGBoost: ターゲット 'target_389' の処理を開始...
#   > 最終FoldのRMSE: 0.0197
#
# [391/424] XGBoost: ターゲット 'target_390' の処理を開始...
#   > 最終FoldのRMSE: 0.0372
#
# [392/424] XGBoost: ターゲット 'target_391' の処理を開始...
#   > 最終FoldのRMSE: 0.0406
#
# [393/424] XGBoost: ターゲット 'target_392' の処理を開始...
#   > 最終FoldのRMSE: 0.0266
#
# [394/424] XGBoost: ターゲット 'target_393' の処理を開始...
#   > 最終FoldのRMSE: 0.0738
#
# [395/424] XGBoost: ターゲット 'target_394' の処理を開始...
#   > 最終FoldのRMSE: 0.0441
#
# [396/424] XGBoost: ターゲット 'target_395' の処理を開始...
#   > 最終FoldのRMSE: 0.0222
#
# [397/424] XGBoost: ターゲット 'target_396' の処理を開始...
#   > 最終FoldのRMSE: 0.0491
#
# [398/424] XGBoost: ターゲット 'target_397' の処理を開始...
#   > 最終FoldのRMSE: 0.0315
#
# [399/424] XGBoost: ターゲット 'target_398' の処理を開始...
#   > 最終FoldのRMSE: 0.0278
#
# [400/424] XGBoost: ターゲット 'target_399' の処理を開始...
#   > 最終FoldのRMSE: 0.0380
#
# [401/424] XGBoost: ターゲット 'target_400' の処理を開始...
#   > 最終FoldのRMSE: 0.0229
#
# [402/424] XGBoost: ターゲット 'target_401' の処理を開始...
#   > 最終FoldのRMSE: 0.0271
#
# [403/424] XGBoost: ターゲット 'target_402' の処理を開始...
#   > 最終FoldのRMSE: 0.0238
#
# [404/424] XGBoost: ターゲット 'target_403' の処理を開始...
#   > 最終FoldのRMSE: 0.0374
#
# [405/424] XGBoost: ターゲット 'target_404' の処理を開始...
#   > 最終FoldのRMSE: 0.0679
#
# [406/424] XGBoost: ターゲット 'target_405' の処理を開始...
#   > 最終FoldのRMSE: 0.0195
#
# [407/424] XGBoost: ターゲット 'target_406' の処理を開始...
#   > 最終FoldのRMSE: 0.0232
#
# [408/424] XGBoost: ターゲット 'target_407' の処理を開始...
#   > 最終FoldのRMSE: 0.0259
#
# [409/424] XGBoost: ターゲット 'target_408' の処理を開始...
#   > 最終FoldのRMSE: 0.0205
#
# [410/424] XGBoost: ターゲット 'target_409' の処理を開始...
#   > 最終FoldのRMSE: 0.0187
#
# [411/424] XGBoost: ターゲット 'target_410' の処理を開始...
#   > 最終FoldのRMSE: 0.0257
#
# [412/424] XGBoost: ターゲット 'target_411' の処理を開始...
#   > 最終FoldのRMSE: 0.0583
#
# [413/424] XGBoost: ターゲット 'target_412' の処理を開始...
#   > 最終FoldのRMSE: 0.0511
#
# [414/424] XGBoost: ターゲット 'target_413' の処理を開始...
#   > 最終FoldのRMSE: 0.0291
#
# [415/424] XGBoost: ターゲット 'target_414' の処理を開始...
#   > 最終FoldのRMSE: 0.0257
#
# [416/424] XGBoost: ターゲット 'target_415' の処理を開始...
#   > 最終FoldのRMSE: 0.0193
#
# [417/424] XGBoost: ターゲット 'target_416' の処理を開始...
#   > 最終FoldのRMSE: 0.0261
#
# [418/424] XGBoost: ターゲット 'target_417' の処理を開始...
#   > 最終FoldのRMSE: 0.0273
#
# [419/424] XGBoost: ターゲット 'target_418' の処理を開始...
#   > 最終FoldのRMSE: 0.0249
#
# [420/424] XGBoost: ターゲット 'target_419' の処理を開始...
#   > 最終FoldのRMSE: 0.0230
#
# [421/424] XGBoost: ターゲット 'target_420' の処理を開始...
#   > 最終FoldのRMSE: 0.0314
#
# [422/424] XGBoost: ターゲット 'target_421' の処理を開始...
#   > 最終FoldのRMSE: 0.0374
#
# [423/424] XGBoost: ターゲット 'target_422' の処理を開始...
#   > 最終FoldのRMSE: 0.0200
#
# [424/424] XGBoost: ターゲット 'target_423' の処理を開始...
#   > 最終FoldのRMSE: 0.0545
#
# XGBoostのOOF予測をCSVファイルとして保存しました。
